# %% [markdown]
# # Getting started with Word2Vec in Gensim and making it work!
#
# The idea behind Word2Vec is pretty simple. We are making and assumption that you can tell the meaning of a word by the company it keeps. This is analogous to the saying *show me your friends, and I'll tell who you are*. So if you have two words that have very similar neighbors (i.e. the usage context is about the same), then these words are probably quite similar in meaning or are at least highly related. For example, the words `shocked`,`appalled` and `astonished` are typically used in a similar context.
#
# In this tutorial, you will learn how to use the Gensim implementation of Word2Vec and actually get it to work! I have heard a lot of complaints about poor performance etc, but its really a combination of two things, (1) your input data and (2) your parameter settings. Note that the training algorithms in this package were ported from the [original Word2Vec implementation by Google](https://arxiv.org/pdf/1301.3781.pdf) and extended with additional functionality.

# %% [markdown]
# ### Imports and logging
#
# First, we start with our imports and get logging established:

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ### Dataset
# Next, is our dataset. The secret to getting Word2Vec really working for you is to have lots and lots of text data. In this case I am going to use data from the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset. This dataset has full user reviews of cars and hotels. I have specifically concatenated all of the hotel reviews into one big file which is about 97MB compressed and 229MB uncompressed. We will use the compressed file for this tutorial. Each line in this file represents a hotel review. You can download the OpinRank Word2Vec dataset here.
#
# To avoid confusion, while gensim’s word2vec tutorial says that you need to pass it a sequence of sentences as its input, you can always pass it a whole review as a sentence (i.e. a much larger size of text), and it should not make much of a difference.
#
# Now, let's take a closer look at this data below by printing the first line. You can see that this is a pretty hefty review.

# %%
data_file="./data/reviews_data.txt.gz"

with gzip.open('./data/reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in Beijing, then you will be ok.I chose to have some breakfast in the hotel, which was really tasty and there was a good selection of dishes. There are a couple of computers to use in the communal area, as well as a pool table. There is also a small swimming pool and a gym area.I would definitely stay in this hotel again, but only if I did not plan to travel to central Beijing, as it can take a long time. The location is ok if you plan to do a lot of shopping, as there is a big shopping centre just few minutes away from the hotel and there are plenty of eating options around, including restaurants that serve a dog meat!\t\r\n"

# %% [markdown]
# ### Read files into a list
# Now that we've had a sneak peak of our dataset, we can read it into a list so that we can pass this on to the Word2Vec model. Notice in the code below, that I am directly reading the
# compressed file. I'm also doing a mild pre-processing of the reviews using `gensim.utils.simple_preprocess (line)`. This does some basic pre-processing such as tokenization, lowercasing, etc and returns back a list of tokens (words). Documentation of this pre-processing method can be found on the official [Gensim documentation site](https://radimrehurek.com/gensim/utils.html).

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open(input_file, 'rb') as f:
        for i, line in enumerate(f): 

            if (i%10000==0):
                logging.info("read {0} reviews".format(i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess(line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list(read_input(data_file))
logging.info ("Done reading data file")
# Out:
# 2020-04-01 00:38:23,061 : INFO : reading file reviews_data.txt.gz...this may take a while
# 2020-04-01 00:38:23,069 : INFO : read 0 reviews
# 2020-04-01 00:38:25,770 : INFO : read 10000 reviews
# 2020-04-01 00:38:28,682 : INFO : read 20000 reviews
# 2020-04-01 00:38:32,195 : INFO : read 30000 reviews
# 2020-04-01 00:38:35,394 : INFO : read 40000 reviews
# 2020-04-01 00:38:39,075 : INFO : read 50000 reviews
# 2020-04-01 00:38:42,877 : INFO : read 60000 reviews
# 2020-04-01 00:38:45,686 : INFO : read 70000 reviews
# 2020-04-01 00:38:48,097 : INFO : read 80000 reviews
# 2020-04-01 00:38:50,734 : INFO : read 90000 reviews
# 2020-04-01 00:38:53,260 : INFO : read 100000 reviews
# 2020-04-01 00:38:56,064 : INFO : read 110000 reviews
# 2020-04-01 00:38:58,919 : INFO : read 120000 reviews
# 2020-04-01 00:39:01,593 : INFO : read 130000 reviews
# 2020-04-01 00:39:04,271 : INFO : read 140000 reviews
# 2020-04-01 00:39:06,877 : INFO : read 150000 reviews
# 2020-04-01 00:39:10,757 : INFO : read 160000 reviews
# 2020-04-01 00:39:15,198 : INFO : read 170000 reviews
# 2020-04-01 00:39:18,274 : INFO : read 180000 reviews
# 2020-04-01 00:39:20,953 : INFO : read 190000 reviews
# 2020-04-01 00:39:23,953 : INFO : read 200000 reviews
# 2020-04-01 00:39:27,594 : INFO : read 210000 reviews
# 2020-04-01 00:39:30,422 : INFO : read 220000 reviews
# 2020-04-01 00:39:33,121 : INFO : read 230000 reviews
# 2020-04-01 00:39:35,895 : INFO : read 240000 reviews
# 2020-04-01 00:39:40,301 : INFO : read 250000 reviews
# 2020-04-01 00:39:42,683 : INFO : Done reading data file

# %% [markdown]
# ## Training the Word2Vec model
#
# Training the model is fairly straightforward. You just instantiate Word2Vec and pass the reviews that we read in the previous step (the `documents`). So, we are essentially passing on a list of lists. Where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary. And by vocabulary, I mean a set of unique words.
#
# After building the vocabulary, we just need to call `train(...)` to start training the Word2Vec model. Training on the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset takes about 10 minutes so please be patient while running your code on this dataset.
#
# Behind the scenes we are actually training a simple neural network with a single hidden layer. But, we are actually not going to use the neural network after training. Instead, the goal is to learn the weights of the hidden layer. These weights are essentially the word vectors that we’re trying to learn.

# %%
model = gensim.models.Word2Vec(documents, size=150, window=10, min_count=2, workers=10)
model.train(documents, total_examples=len(documents), epochs=10)
# Out:
# 2020-04-01 00:40:04,577 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2020-04-01 00:40:04,609 : INFO : collecting all words and their counts
# 2020-04-01 00:40:04,615 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-01 00:40:05,039 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2020-04-01 00:40:05,567 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2020-04-01 00:40:06,139 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2020-04-01 00:40:06,754 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2020-04-01 00:40:07,246 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2020-04-01 00:40:07,707 : INFO : PROGRESS: at sentence #60000, processed 11013726 words, keeping 76786 word types
# 2020-04-01 00:40:08,128 : INFO : PROGRESS: at sentence #70000, processed 12637528 words, keeping 83199 word types
# 2020-04-01 00:40:08,495 : INFO : PROGRESS: at sentence #80000, processed 14099754 words, keeping 88459 word types
# 2020-04-01 00:40:09,019 : INFO : PROGRESS: at sentence #90000, processed 15662152 words, keeping 93357 word types
# 2020-04-01 00:40:09,465 : INFO : PROGRESS: at sentence #100000, processed 17164490 words, keeping 97886 word types
# 2020-04-01 00:40:09,927 : INFO : PROGRESS: at sentence #110000, processed 18652295 words, keeping 102132 word types
# 2020-04-01 00:40:10,305 : INFO : PROGRESS: at sentence #120000, processed 20152532 words, keeping 105923 word types
# 2020-04-01 00:40:10,859 : INFO : PROGRESS: at sentence #130000, processed 21684333 words, keeping 110104 word types
# 2020-04-01 00:40:11,343 : INFO : PROGRESS: at sentence #140000, processed 23330209 words, keeping 114108 word types
# 2020-04-01 00:40:11,808 : INFO : PROGRESS: at sentence #150000, processed 24838757 words, keeping 118174 word types
# 2020-04-01 00:40:12,298 : INFO : PROGRESS: at sentence #160000, processed 26390913 words, keeping 118670 word types
# 2020-04-01 00:40:12,775 : INFO : PROGRESS: at sentence #170000, processed 27913919 words, keeping 123356 word types
# 2020-04-01 00:40:13,252 : INFO : PROGRESS: at sentence #180000, processed 29535615 words, keeping 126748 word types
# 2020-04-01 00:40:13,678 : INFO : PROGRESS: at sentence #190000, processed 31096462 words, keeping 129847 word types
# 2020-04-01 00:40:14,186 : INFO : PROGRESS: at sentence #200000, processed 32805274 words, keeping 133255 word types
# 2020-04-01 00:40:14,672 : INFO : PROGRESS: at sentence #210000, processed 34434201 words, keeping 136364 word types
# 2020-04-01 00:40:15,207 : INFO : PROGRESS: at sentence #220000, processed 36083485 words, keeping 139418 word types
# 2020-04-01 00:40:15,709 : INFO : PROGRESS: at sentence #230000, processed 37571765 words, keeping 142399 word types
# 2020-04-01 00:40:16,249 : INFO : PROGRESS: at sentence #240000, processed 39138193 words, keeping 145232 word types
# 2020-04-01 00:40:16,718 : INFO : PROGRESS: at sentence #250000, processed 40695052 words, keeping 147966 word types
# 2020-04-01 00:40:17,002 : INFO : collected 150059 word types from a corpus of 41519358 raw words and 255404 sentences
# 2020-04-01 00:40:17,004 : INFO : Loading a fresh vocabulary
# 2020-04-01 00:40:17,310 : INFO : effective_min_count=2 retains 70537 unique words (47% of original 150059, drops 79522)
# 2020-04-01 00:40:17,311 : INFO : effective_min_count=2 leaves 41439836 word corpus (99% of original 41519358, drops 79522)
# 2020-04-01 00:40:17,712 : INFO : deleting the raw counts dictionary of 150059 items
# 2020-04-01 00:40:17,731 : INFO : sample=0.001 downsamples 55 most-common words
# 2020-04-01 00:40:17,732 : INFO : downsampling leaves estimated 30349251 word corpus (73.2% of prior 41439836)
# 2020-04-01 00:40:18,102 : INFO : estimated required memory for 70537 words and 150 dimensions: 119912900 bytes
# 2020-04-01 00:40:18,104 : INFO : resetting layer weights
# 2020-04-01 00:40:36,722 : INFO : training model with 10 workers on 70537 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2020-04-01 00:40:37,796 : INFO : EPOCH 1 - PROGRESS: at 3.00% examples, 928910 words/s, in_qsize 18, out_qsize 7
# 2020-04-01 00:40:38,768 : INFO : EPOCH 1 - PROGRESS: at 6.30% examples, 969282 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:40:39,779 : INFO : EPOCH 1 - PROGRESS: at 9.59% examples, 997217 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:40:40,780 : INFO : EPOCH 1 - PROGRESS: at 12.32% examples, 1009870 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:40:41,785 : INFO : EPOCH 1 - PROGRESS: at 15.45% examples, 1017414 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:40:42,785 : INFO : EPOCH 1 - PROGRESS: at 18.19% examples, 1014877 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:40:43,787 : INFO : EPOCH 1 - PROGRESS: at 20.84% examples, 1017071 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:40:44,802 : INFO : EPOCH 1 - PROGRESS: at 23.79% examples, 1016204 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:40:45,803 : INFO : EPOCH 1 - PROGRESS: at 27.22% examples, 1015257 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:40:46,821 : INFO : EPOCH 1 - PROGRESS: at 30.77% examples, 1010874 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:40:47,826 : INFO : EPOCH 1 - PROGRESS: at 34.22% examples, 1007653 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:40:48,829 : INFO : EPOCH 1 - PROGRESS: at 37.48% examples, 1001635 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:40:49,834 : INFO : EPOCH 1 - PROGRESS: at 41.06% examples, 1000654 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:40:50,836 : INFO : EPOCH 1 - PROGRESS: at 44.68% examples, 999090 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:40:51,837 : INFO : EPOCH 1 - PROGRESS: at 48.05% examples, 997772 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:40:52,853 : INFO : EPOCH 1 - PROGRESS: at 51.48% examples, 995593 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:40:53,856 : INFO : EPOCH 1 - PROGRESS: at 54.63% examples, 994161 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:40:54,859 : INFO : EPOCH 1 - PROGRESS: at 58.10% examples, 993272 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:40:55,873 : INFO : EPOCH 1 - PROGRESS: at 61.48% examples, 991770 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:40:56,885 : INFO : EPOCH 1 - PROGRESS: at 65.09% examples, 991001 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:40:57,901 : INFO : EPOCH 1 - PROGRESS: at 68.47% examples, 991899 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:40:58,920 : INFO : EPOCH 1 - PROGRESS: at 71.70% examples, 991200 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:40:59,946 : INFO : EPOCH 1 - PROGRESS: at 75.13% examples, 990474 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:00,984 : INFO : EPOCH 1 - PROGRESS: at 78.27% examples, 989656 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:41:01,988 : INFO : EPOCH 1 - PROGRESS: at 81.54% examples, 989954 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:02,997 : INFO : EPOCH 1 - PROGRESS: at 84.77% examples, 989685 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:04,012 : INFO : EPOCH 1 - PROGRESS: at 88.32% examples, 989855 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:05,012 : INFO : EPOCH 1 - PROGRESS: at 91.80% examples, 989894 words/s, in_qsize 18, out_qsize 0
# 2020-04-01 00:41:06,029 : INFO : EPOCH 1 - PROGRESS: at 95.15% examples, 989042 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:07,039 : INFO : EPOCH 1 - PROGRESS: at 98.53% examples, 988670 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:07,394 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:41:07,406 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:41:07,409 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:41:07,414 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:41:07,419 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:41:07,428 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:41:07,435 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:41:07,437 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:41:07,439 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:41:07,442 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:41:07,443 : INFO : EPOCH - 1 : training on 41519358 raw words (30350778 effective words) took 30.7s, 989159 effective words/s
# 2020-04-01 00:41:08,456 : INFO : EPOCH 2 - PROGRESS: at 3.11% examples, 958551 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:09,474 : INFO : EPOCH 2 - PROGRESS: at 6.43% examples, 981760 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:10,479 : INFO : EPOCH 2 - PROGRESS: at 9.49% examples, 983607 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:11,488 : INFO : EPOCH 2 - PROGRESS: at 12.07% examples, 981379 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:12,494 : INFO : EPOCH 2 - PROGRESS: at 14.94% examples, 982623 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:41:13,509 : INFO : EPOCH 2 - PROGRESS: at 17.75% examples, 984722 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:14,527 : INFO : EPOCH 2 - PROGRESS: at 20.43% examples, 985847 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:15,545 : INFO : EPOCH 2 - PROGRESS: at 23.31% examples, 985921 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:41:16,559 : INFO : EPOCH 2 - PROGRESS: at 26.42% examples, 984473 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:41:17,574 : INFO : EPOCH 2 - PROGRESS: at 29.97% examples, 983290 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:18,587 : INFO : EPOCH 2 - PROGRESS: at 33.48% examples, 981338 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:41:19,614 : INFO : EPOCH 2 - PROGRESS: at 36.91% examples, 980460 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:20,621 : INFO : EPOCH 2 - PROGRESS: at 40.43% examples, 980923 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:41:21,629 : INFO : EPOCH 2 - PROGRESS: at 44.06% examples, 980814 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:41:22,633 : INFO : EPOCH 2 - PROGRESS: at 47.58% examples, 981921 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:23,652 : INFO : EPOCH 2 - PROGRESS: at 51.09% examples, 982373 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:24,674 : INFO : EPOCH 2 - PROGRESS: at 54.37% examples, 982215 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:25,681 : INFO : EPOCH 2 - PROGRESS: at 57.78% examples, 981061 words/s, in_qsize 19, out_qsize 2
# 2020-04-01 00:41:26,685 : INFO : EPOCH 2 - PROGRESS: at 61.20% examples, 981023 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:27,695 : INFO : EPOCH 2 - PROGRESS: at 64.74% examples, 979933 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:28,714 : INFO : EPOCH 2 - PROGRESS: at 68.07% examples, 980485 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:29,728 : INFO : EPOCH 2 - PROGRESS: at 71.15% examples, 979189 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:30,732 : INFO : EPOCH 2 - PROGRESS: at 74.64% examples, 979652 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:31,740 : INFO : EPOCH 2 - PROGRESS: at 77.70% examples, 979621 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:32,752 : INFO : EPOCH 2 - PROGRESS: at 80.92% examples, 979707 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:41:33,772 : INFO : EPOCH 2 - PROGRESS: at 84.27% examples, 980012 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:34,778 : INFO : EPOCH 2 - PROGRESS: at 87.71% examples, 980874 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:35,792 : INFO : EPOCH 2 - PROGRESS: at 91.02% examples, 978862 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:36,811 : INFO : EPOCH 2 - PROGRESS: at 94.43% examples, 978837 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:37,812 : INFO : EPOCH 2 - PROGRESS: at 97.78% examples, 978818 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:38,405 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:41:38,415 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:41:38,418 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:41:38,432 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:41:38,435 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:41:38,437 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:41:38,439 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:41:38,441 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:41:38,447 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:41:38,449 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:41:38,450 : INFO : EPOCH - 2 : training on 41519358 raw words (30346607 effective words) took 31.0s, 979072 effective words/s
# 2020-04-01 00:41:39,474 : INFO : EPOCH 3 - PROGRESS: at 3.10% examples, 945141 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:40,488 : INFO : EPOCH 3 - PROGRESS: at 6.38% examples, 969975 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:41,512 : INFO : EPOCH 3 - PROGRESS: at 9.43% examples, 964933 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:41:42,512 : INFO : EPOCH 3 - PROGRESS: at 11.88% examples, 959026 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:43,526 : INFO : EPOCH 3 - PROGRESS: at 14.58% examples, 951629 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:44,533 : INFO : EPOCH 3 - PROGRESS: at 17.30% examples, 953191 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:45,535 : INFO : EPOCH 3 - PROGRESS: at 19.71% examples, 946778 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:46,554 : INFO : EPOCH 3 - PROGRESS: at 22.48% examples, 944456 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:47,567 : INFO : EPOCH 3 - PROGRESS: at 24.84% examples, 938137 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:48,569 : INFO : EPOCH 3 - PROGRESS: at 28.20% examples, 933693 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:41:49,589 : INFO : EPOCH 3 - PROGRESS: at 31.44% examples, 929124 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:50,599 : INFO : EPOCH 3 - PROGRESS: at 34.51% examples, 924963 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:41:51,605 : INFO : EPOCH 3 - PROGRESS: at 37.53% examples, 920588 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 00:41:52,617 : INFO : EPOCH 3 - PROGRESS: at 40.64% examples, 916794 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:53,623 : INFO : EPOCH 3 - PROGRESS: at 43.84% examples, 913056 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:54,647 : INFO : EPOCH 3 - PROGRESS: at 46.92% examples, 908629 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:41:55,676 : INFO : EPOCH 3 - PROGRESS: at 50.00% examples, 905395 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:41:56,689 : INFO : EPOCH 3 - PROGRESS: at 52.74% examples, 900427 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:41:57,708 : INFO : EPOCH 3 - PROGRESS: at 55.69% examples, 897025 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:41:58,741 : INFO : EPOCH 3 - PROGRESS: at 58.62% examples, 893748 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:41:59,763 : INFO : EPOCH 3 - PROGRESS: at 61.50% examples, 889980 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:42:00,787 : INFO : EPOCH 3 - PROGRESS: at 64.33% examples, 883461 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:01,788 : INFO : EPOCH 3 - PROGRESS: at 66.92% examples, 879335 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:02,800 : INFO : EPOCH 3 - PROGRESS: at 69.71% examples, 877105 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:03,809 : INFO : EPOCH 3 - PROGRESS: at 72.39% examples, 874644 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:04,810 : INFO : EPOCH 3 - PROGRESS: at 75.35% examples, 873920 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:05,824 : INFO : EPOCH 3 - PROGRESS: at 77.90% examples, 871493 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:42:06,838 : INFO : EPOCH 3 - PROGRESS: at 80.56% examples, 869281 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:42:07,839 : INFO : EPOCH 3 - PROGRESS: at 83.31% examples, 867604 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:08,839 : INFO : EPOCH 3 - PROGRESS: at 85.77% examples, 864573 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:42:09,840 : INFO : EPOCH 3 - PROGRESS: at 88.81% examples, 863655 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:10,857 : INFO : EPOCH 3 - PROGRESS: at 91.63% examples, 861572 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:11,863 : INFO : EPOCH 3 - PROGRESS: at 94.38% examples, 859788 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:12,866 : INFO : EPOCH 3 - PROGRESS: at 97.15% examples, 858178 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:13,827 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:42:13,838 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:42:13,841 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:42:13,843 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:42:13,858 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:42:13,862 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:42:13,864 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:42:13,865 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:42:13,879 : INFO : EPOCH 3 - PROGRESS: at 99.98% examples, 856549 words/s, in_qsize 1, out_qsize 1
# 2020-04-01 00:42:13,880 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:42:13,884 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:42:13,886 : INFO : EPOCH - 3 : training on 41519358 raw words (30345587 effective words) took 35.4s, 856578 effective words/s
# 2020-04-01 00:42:14,907 : INFO : EPOCH 4 - PROGRESS: at 2.43% examples, 764274 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:15,908 : INFO : EPOCH 4 - PROGRESS: at 5.16% examples, 792916 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:16,908 : INFO : EPOCH 4 - PROGRESS: at 7.68% examples, 790044 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:42:17,911 : INFO : EPOCH 4 - PROGRESS: at 10.00% examples, 793103 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:18,930 : INFO : EPOCH 4 - PROGRESS: at 12.15% examples, 793953 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:19,936 : INFO : EPOCH 4 - PROGRESS: at 14.54% examples, 796288 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:20,936 : INFO : EPOCH 4 - PROGRESS: at 16.81% examples, 795825 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:21,945 : INFO : EPOCH 4 - PROGRESS: at 18.98% examples, 797050 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:22,952 : INFO : EPOCH 4 - PROGRESS: at 20.97% examples, 795556 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:23,956 : INFO : EPOCH 4 - PROGRESS: at 23.33% examples, 793797 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:24,966 : INFO : EPOCH 4 - PROGRESS: at 25.70% examples, 792885 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:42:25,976 : INFO : EPOCH 4 - PROGRESS: at 28.66% examples, 792970 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:42:26,990 : INFO : EPOCH 4 - PROGRESS: at 31.57% examples, 792143 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:27,998 : INFO : EPOCH 4 - PROGRESS: at 34.27% examples, 791846 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:29,001 : INFO : EPOCH 4 - PROGRESS: at 36.97% examples, 790369 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:30,004 : INFO : EPOCH 4 - PROGRESS: at 39.87% examples, 792103 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:31,006 : INFO : EPOCH 4 - PROGRESS: at 42.73% examples, 791967 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:32,024 : INFO : EPOCH 4 - PROGRESS: at 45.72% examples, 791721 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:33,030 : INFO : EPOCH 4 - PROGRESS: at 48.49% examples, 792674 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:34,050 : INFO : EPOCH 4 - PROGRESS: at 51.18% examples, 791149 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:35,065 : INFO : EPOCH 4 - PROGRESS: at 53.72% examples, 790209 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:42:36,086 : INFO : EPOCH 4 - PROGRESS: at 56.57% examples, 790020 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:37,117 : INFO : EPOCH 4 - PROGRESS: at 59.19% examples, 787621 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:42:38,136 : INFO : EPOCH 4 - PROGRESS: at 61.96% examples, 788034 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:42:39,152 : INFO : EPOCH 4 - PROGRESS: at 64.92% examples, 787401 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:42:40,163 : INFO : EPOCH 4 - PROGRESS: at 67.43% examples, 786575 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:41,168 : INFO : EPOCH 4 - PROGRESS: at 70.09% examples, 787676 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:42:42,193 : INFO : EPOCH 4 - PROGRESS: at 72.90% examples, 788209 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:43,195 : INFO : EPOCH 4 - PROGRESS: at 75.56% examples, 788561 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:42:44,196 : INFO : EPOCH 4 - PROGRESS: at 78.03% examples, 788810 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:45,213 : INFO : EPOCH 4 - PROGRESS: at 80.73% examples, 789668 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:46,214 : INFO : EPOCH 4 - PROGRESS: at 83.48% examples, 790385 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:47,229 : INFO : EPOCH 4 - PROGRESS: at 86.02% examples, 790232 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:48,231 : INFO : EPOCH 4 - PROGRESS: at 88.99% examples, 790940 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:42:49,238 : INFO : EPOCH 4 - PROGRESS: at 91.73% examples, 790682 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:50,253 : INFO : EPOCH 4 - PROGRESS: at 94.48% examples, 790839 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:51,266 : INFO : EPOCH 4 - PROGRESS: at 97.24% examples, 790809 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:42:52,169 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:42:52,195 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:42:52,200 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:42:52,207 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:42:52,216 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:42:52,225 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:42:52,227 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:42:52,233 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:42:52,236 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:42:52,247 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:42:52,249 : INFO : EPOCH - 4 : training on 41519358 raw words (30348984 effective words) took 38.4s, 791315 effective words/s
# 2020-04-01 00:42:53,269 : INFO : EPOCH 5 - PROGRESS: at 2.43% examples, 766755 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:54,297 : INFO : EPOCH 5 - PROGRESS: at 5.16% examples, 783818 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:55,305 : INFO : EPOCH 5 - PROGRESS: at 7.77% examples, 791176 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:56,322 : INFO : EPOCH 5 - PROGRESS: at 10.13% examples, 794633 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:57,329 : INFO : EPOCH 5 - PROGRESS: at 12.19% examples, 792835 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:58,356 : INFO : EPOCH 5 - PROGRESS: at 14.60% examples, 792646 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:42:59,380 : INFO : EPOCH 5 - PROGRESS: at 16.96% examples, 794151 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:00,382 : INFO : EPOCH 5 - PROGRESS: at 19.07% examples, 793562 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:43:01,394 : INFO : EPOCH 5 - PROGRESS: at 21.18% examples, 792731 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:02,418 : INFO : EPOCH 5 - PROGRESS: at 23.51% examples, 793345 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:03,457 : INFO : EPOCH 5 - PROGRESS: at 26.06% examples, 793097 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:43:04,473 : INFO : EPOCH 5 - PROGRESS: at 29.10% examples, 793941 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:43:05,477 : INFO : EPOCH 5 - PROGRESS: at 31.88% examples, 790868 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:06,499 : INFO : EPOCH 5 - PROGRESS: at 34.46% examples, 787912 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:07,510 : INFO : EPOCH 5 - PROGRESS: at 37.18% examples, 787729 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:43:08,521 : INFO : EPOCH 5 - PROGRESS: at 39.94% examples, 786094 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:43:09,536 : INFO : EPOCH 5 - PROGRESS: at 42.75% examples, 784912 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:43:10,539 : INFO : EPOCH 5 - PROGRESS: at 45.77% examples, 786059 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:11,555 : INFO : EPOCH 5 - PROGRESS: at 48.49% examples, 786127 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:43:12,572 : INFO : EPOCH 5 - PROGRESS: at 51.27% examples, 786106 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:13,581 : INFO : EPOCH 5 - PROGRESS: at 53.85% examples, 786383 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:14,602 : INFO : EPOCH 5 - PROGRESS: at 56.72% examples, 786679 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:43:15,604 : INFO : EPOCH 5 - PROGRESS: at 59.44% examples, 786648 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:43:16,620 : INFO : EPOCH 5 - PROGRESS: at 62.10% examples, 785988 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:43:17,638 : INFO : EPOCH 5 - PROGRESS: at 65.12% examples, 786580 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:43:18,661 : INFO : EPOCH 5 - PROGRESS: at 67.82% examples, 786743 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:43:19,667 : INFO : EPOCH 5 - PROGRESS: at 70.32% examples, 786478 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:43:20,675 : INFO : EPOCH 5 - PROGRESS: at 73.06% examples, 786774 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:21,678 : INFO : EPOCH 5 - PROGRESS: at 75.70% examples, 786923 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:22,693 : INFO : EPOCH 5 - PROGRESS: at 78.19% examples, 786883 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:23,695 : INFO : EPOCH 5 - PROGRESS: at 80.76% examples, 786978 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:24,703 : INFO : EPOCH 5 - PROGRESS: at 83.41% examples, 786710 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:25,716 : INFO : EPOCH 5 - PROGRESS: at 85.98% examples, 786942 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:43:26,720 : INFO : EPOCH 5 - PROGRESS: at 88.91% examples, 787469 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:27,728 : INFO : EPOCH 5 - PROGRESS: at 91.66% examples, 787288 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:28,733 : INFO : EPOCH 5 - PROGRESS: at 94.30% examples, 786943 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:43:29,742 : INFO : EPOCH 5 - PROGRESS: at 97.02% examples, 786936 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:43:30,731 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:43:30,746 : INFO : EPOCH 5 - PROGRESS: at 99.81% examples, 787189 words/s, in_qsize 7, out_qsize 3
# 2020-04-01 00:43:30,752 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:43:30,754 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:43:30,756 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:43:30,761 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:43:30,773 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:43:30,776 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:43:30,784 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:43:30,787 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:43:30,790 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:43:30,792 : INFO : EPOCH - 5 : training on 41519358 raw words (30348715 effective words) took 38.5s, 787670 effective words/s
# 2020-04-01 00:43:30,794 : INFO : training on a 207596790 raw words (151740671 effective words) took 174.1s, 871724 effective words/s
# 2020-04-01 00:43:30,796 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-04-01 00:43:30,797 : INFO : training model with 10 workers on 70537 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2020-04-01 00:43:31,821 : INFO : EPOCH 1 - PROGRESS: at 2.42% examples, 755793 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:43:32,821 : INFO : EPOCH 1 - PROGRESS: at 5.10% examples, 781759 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:43:33,823 : INFO : EPOCH 1 - PROGRESS: at 7.60% examples, 779527 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:34,825 : INFO : EPOCH 1 - PROGRESS: at 9.86% examples, 780007 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:35,826 : INFO : EPOCH 1 - PROGRESS: at 12.02% examples, 784779 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:36,830 : INFO : EPOCH 1 - PROGRESS: at 14.26% examples, 783012 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:37,835 : INFO : EPOCH 1 - PROGRESS: at 16.60% examples, 787155 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:38,867 : INFO : EPOCH 1 - PROGRESS: at 18.85% examples, 788100 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:43:39,886 : INFO : EPOCH 1 - PROGRESS: at 20.86% examples, 788050 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:40,890 : INFO : EPOCH 1 - PROGRESS: at 23.20% examples, 787158 words/s, in_qsize 19, out_qsize 3
# 2020-04-01 00:43:41,916 : INFO : EPOCH 1 - PROGRESS: at 25.70% examples, 790192 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:43:42,924 : INFO : EPOCH 1 - PROGRESS: at 28.58% examples, 788924 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:43:43,931 : INFO : EPOCH 1 - PROGRESS: at 31.54% examples, 789941 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 00:43:44,934 : INFO : EPOCH 1 - PROGRESS: at 34.23% examples, 790053 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:45,946 : INFO : EPOCH 1 - PROGRESS: at 36.99% examples, 789167 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:43:46,969 : INFO : EPOCH 1 - PROGRESS: at 39.80% examples, 788737 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:47,975 : INFO : EPOCH 1 - PROGRESS: at 42.70% examples, 789060 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:48,978 : INFO : EPOCH 1 - PROGRESS: at 45.60% examples, 788010 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:49,979 : INFO : EPOCH 1 - PROGRESS: at 48.39% examples, 789671 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:50,985 : INFO : EPOCH 1 - PROGRESS: at 51.10% examples, 788830 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:51,998 : INFO : EPOCH 1 - PROGRESS: at 53.68% examples, 788776 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:53,008 : INFO : EPOCH 1 - PROGRESS: at 56.51% examples, 789063 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:43:54,008 : INFO : EPOCH 1 - PROGRESS: at 59.27% examples, 789637 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:55,021 : INFO : EPOCH 1 - PROGRESS: at 62.03% examples, 789852 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:43:56,045 : INFO : EPOCH 1 - PROGRESS: at 65.07% examples, 790034 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:43:57,058 : INFO : EPOCH 1 - PROGRESS: at 67.60% examples, 789034 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:43:58,070 : INFO : EPOCH 1 - PROGRESS: at 70.21% examples, 789321 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:43:59,079 : INFO : EPOCH 1 - PROGRESS: at 72.94% examples, 789470 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:00,098 : INFO : EPOCH 1 - PROGRESS: at 75.50% examples, 788108 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:44:01,112 : INFO : EPOCH 1 - PROGRESS: at 78.01% examples, 788511 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:02,125 : INFO : EPOCH 1 - PROGRESS: at 80.66% examples, 788959 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:03,138 : INFO : EPOCH 1 - PROGRESS: at 83.38% examples, 789195 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:04,152 : INFO : EPOCH 1 - PROGRESS: at 85.96% examples, 789301 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:44:05,155 : INFO : EPOCH 1 - PROGRESS: at 88.88% examples, 789799 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:06,166 : INFO : EPOCH 1 - PROGRESS: at 91.61% examples, 789289 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:44:07,169 : INFO : EPOCH 1 - PROGRESS: at 94.28% examples, 789145 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 00:44:08,185 : INFO : EPOCH 1 - PROGRESS: at 97.06% examples, 789479 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:44:09,168 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:44:09,180 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:44:09,186 : INFO : EPOCH 1 - PROGRESS: at 99.83% examples, 789546 words/s, in_qsize 7, out_qsize 1
# 2020-04-01 00:44:09,189 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:44:09,201 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:44:09,204 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:44:09,209 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:44:09,214 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:44:09,217 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:44:09,223 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:44:09,225 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:44:09,226 : INFO : EPOCH - 1 : training on 41519358 raw words (30348925 effective words) took 38.4s, 789945 effective words/s
# 2020-04-01 00:44:10,240 : INFO : EPOCH 2 - PROGRESS: at 2.35% examples, 743325 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:11,257 : INFO : EPOCH 2 - PROGRESS: at 5.14% examples, 787499 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:44:12,258 : INFO : EPOCH 2 - PROGRESS: at 7.77% examples, 798028 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:13,260 : INFO : EPOCH 2 - PROGRESS: at 10.02% examples, 793893 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:14,275 : INFO : EPOCH 2 - PROGRESS: at 12.08% examples, 788045 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:15,278 : INFO : EPOCH 2 - PROGRESS: at 14.41% examples, 789451 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:16,298 : INFO : EPOCH 2 - PROGRESS: at 16.60% examples, 783659 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:44:17,305 : INFO : EPOCH 2 - PROGRESS: at 18.63% examples, 777877 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:18,313 : INFO : EPOCH 2 - PROGRESS: at 20.54% examples, 774229 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:19,326 : INFO : EPOCH 2 - PROGRESS: at 22.87% examples, 772544 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:44:20,338 : INFO : EPOCH 2 - PROGRESS: at 25.08% examples, 775267 words/s, in_qsize 19, out_qsize 3
# 2020-04-01 00:44:21,339 : INFO : EPOCH 2 - PROGRESS: at 27.98% examples, 775528 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:22,364 : INFO : EPOCH 2 - PROGRESS: at 30.73% examples, 774379 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:44:23,372 : INFO : EPOCH 2 - PROGRESS: at 33.60% examples, 775756 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:24,373 : INFO : EPOCH 2 - PROGRESS: at 36.37% examples, 776980 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:25,374 : INFO : EPOCH 2 - PROGRESS: at 39.09% examples, 776515 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:26,383 : INFO : EPOCH 2 - PROGRESS: at 41.97% examples, 776672 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:44:27,406 : INFO : EPOCH 2 - PROGRESS: at 44.89% examples, 777383 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:44:28,410 : INFO : EPOCH 2 - PROGRESS: at 47.65% examples, 778749 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:29,416 : INFO : EPOCH 2 - PROGRESS: at 50.44% examples, 779199 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:30,417 : INFO : EPOCH 2 - PROGRESS: at 52.94% examples, 778709 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:31,420 : INFO : EPOCH 2 - PROGRESS: at 55.68% examples, 778689 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:32,442 : INFO : EPOCH 2 - PROGRESS: at 58.44% examples, 779261 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:33,451 : INFO : EPOCH 2 - PROGRESS: at 61.22% examples, 779722 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:34,459 : INFO : EPOCH 2 - PROGRESS: at 64.14% examples, 780362 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:35,459 : INFO : EPOCH 2 - PROGRESS: at 66.72% examples, 780426 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:36,475 : INFO : EPOCH 2 - PROGRESS: at 69.47% examples, 781419 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:37,484 : INFO : EPOCH 2 - PROGRESS: at 72.10% examples, 782127 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:38,509 : INFO : EPOCH 2 - PROGRESS: at 74.94% examples, 782542 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:39,520 : INFO : EPOCH 2 - PROGRESS: at 77.48% examples, 783525 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:40,540 : INFO : EPOCH 2 - PROGRESS: at 80.04% examples, 783287 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:44:41,596 : INFO : EPOCH 2 - PROGRESS: at 82.79% examples, 783094 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:44:42,598 : INFO : EPOCH 2 - PROGRESS: at 85.35% examples, 783892 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:43,616 : INFO : EPOCH 2 - PROGRESS: at 88.24% examples, 784173 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:44,630 : INFO : EPOCH 2 - PROGRESS: at 91.10% examples, 784584 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:45,668 : INFO : EPOCH 2 - PROGRESS: at 93.85% examples, 784394 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:46,675 : INFO : EPOCH 2 - PROGRESS: at 96.64% examples, 785095 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:47,676 : INFO : EPOCH 2 - PROGRESS: at 99.29% examples, 784347 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:44:47,882 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:44:47,896 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:44:47,899 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:44:47,905 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:44:47,923 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:44:47,933 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:44:47,936 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:44:47,937 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:44:47,940 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:44:47,947 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:44:47,949 : INFO : EPOCH - 2 : training on 41519358 raw words (30351501 effective words) took 38.7s, 784108 effective words/s
# 2020-04-01 00:44:48,976 : INFO : EPOCH 3 - PROGRESS: at 2.30% examples, 719427 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:49,996 : INFO : EPOCH 3 - PROGRESS: at 4.92% examples, 746125 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:50,997 : INFO : EPOCH 3 - PROGRESS: at 7.54% examples, 767568 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:44:51,997 : INFO : EPOCH 3 - PROGRESS: at 9.82% examples, 771196 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:53,005 : INFO : EPOCH 3 - PROGRESS: at 11.90% examples, 772526 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:54,015 : INFO : EPOCH 3 - PROGRESS: at 14.24% examples, 777865 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:44:55,036 : INFO : EPOCH 3 - PROGRESS: at 16.55% examples, 778922 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:56,036 : INFO : EPOCH 3 - PROGRESS: at 18.70% examples, 780503 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:44:57,046 : INFO : EPOCH 3 - PROGRESS: at 20.68% examples, 780423 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:44:58,047 : INFO : EPOCH 3 - PROGRESS: at 23.05% examples, 781155 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:44:59,072 : INFO : EPOCH 3 - PROGRESS: at 25.39% examples, 782256 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:00,079 : INFO : EPOCH 3 - PROGRESS: at 28.36% examples, 783505 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:01,091 : INFO : EPOCH 3 - PROGRESS: at 31.29% examples, 784635 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:45:02,109 : INFO : EPOCH 3 - PROGRESS: at 34.06% examples, 785807 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:45:03,133 : INFO : EPOCH 3 - PROGRESS: at 36.93% examples, 786461 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:04,146 : INFO : EPOCH 3 - PROGRESS: at 39.77% examples, 787143 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:45:05,152 : INFO : EPOCH 3 - PROGRESS: at 42.65% examples, 786730 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:06,154 : INFO : EPOCH 3 - PROGRESS: at 45.76% examples, 789800 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:07,179 : INFO : EPOCH 3 - PROGRESS: at 48.61% examples, 791148 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:08,199 : INFO : EPOCH 3 - PROGRESS: at 51.48% examples, 791798 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:45:09,201 : INFO : EPOCH 3 - PROGRESS: at 54.07% examples, 792371 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:10,206 : INFO : EPOCH 3 - PROGRESS: at 56.88% examples, 792033 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:11,212 : INFO : EPOCH 3 - PROGRESS: at 59.59% examples, 791628 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:12,222 : INFO : EPOCH 3 - PROGRESS: at 62.31% examples, 791590 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:13,243 : INFO : EPOCH 3 - PROGRESS: at 65.22% examples, 790703 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 00:45:14,247 : INFO : EPOCH 3 - PROGRESS: at 67.88% examples, 791087 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:15,249 : INFO : EPOCH 3 - PROGRESS: at 70.53% examples, 792071 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:16,257 : INFO : EPOCH 3 - PROGRESS: at 73.39% examples, 793183 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:45:17,280 : INFO : EPOCH 3 - PROGRESS: at 75.99% examples, 792765 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:45:18,289 : INFO : EPOCH 3 - PROGRESS: at 78.59% examples, 793678 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:19,297 : INFO : EPOCH 3 - PROGRESS: at 81.15% examples, 793422 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:20,320 : INFO : EPOCH 3 - PROGRESS: at 83.78% examples, 792582 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:21,326 : INFO : EPOCH 3 - PROGRESS: at 86.39% examples, 792577 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:22,341 : INFO : EPOCH 3 - PROGRESS: at 89.21% examples, 791861 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:23,360 : INFO : EPOCH 3 - PROGRESS: at 92.10% examples, 792339 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:45:24,361 : INFO : EPOCH 3 - PROGRESS: at 94.79% examples, 792527 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:25,364 : INFO : EPOCH 3 - PROGRESS: at 97.53% examples, 792443 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:45:26,164 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:45:26,185 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:45:26,188 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:45:26,191 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:45:26,198 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:45:26,204 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:45:26,207 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:45:26,209 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:45:26,224 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:45:26,262 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:45:26,263 : INFO : EPOCH - 3 : training on 41519358 raw words (30349525 effective words) took 38.3s, 792415 effective words/s
# 2020-04-01 00:45:27,284 : INFO : EPOCH 4 - PROGRESS: at 2.43% examples, 763472 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:28,302 : INFO : EPOCH 4 - PROGRESS: at 5.14% examples, 782223 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:45:29,315 : INFO : EPOCH 4 - PROGRESS: at 7.75% examples, 788835 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:45:30,333 : INFO : EPOCH 4 - PROGRESS: at 10.09% examples, 790853 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 00:45:31,353 : INFO : EPOCH 4 - PROGRESS: at 12.23% examples, 793301 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:45:32,370 : INFO : EPOCH 4 - PROGRESS: at 14.65% examples, 794473 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:45:33,380 : INFO : EPOCH 4 - PROGRESS: at 16.96% examples, 795285 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:45:34,385 : INFO : EPOCH 4 - PROGRESS: at 19.14% examples, 797664 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:35,398 : INFO : EPOCH 4 - PROGRESS: at 21.48% examples, 796968 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:36,407 : INFO : EPOCH 4 - PROGRESS: at 23.54% examples, 796506 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:37,414 : INFO : EPOCH 4 - PROGRESS: at 26.00% examples, 795594 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:45:38,422 : INFO : EPOCH 4 - PROGRESS: at 28.96% examples, 794947 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:45:39,431 : INFO : EPOCH 4 - PROGRESS: at 31.92% examples, 795365 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:40,438 : INFO : EPOCH 4 - PROGRESS: at 34.63% examples, 795414 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:45:41,442 : INFO : EPOCH 4 - PROGRESS: at 37.33% examples, 794127 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:42,445 : INFO : EPOCH 4 - PROGRESS: at 40.23% examples, 794692 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:45:43,454 : INFO : EPOCH 4 - PROGRESS: at 43.04% examples, 793246 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:45:44,455 : INFO : EPOCH 4 - PROGRESS: at 46.12% examples, 795237 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:45,477 : INFO : EPOCH 4 - PROGRESS: at 48.82% examples, 794171 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:45:46,494 : INFO : EPOCH 4 - PROGRESS: at 51.58% examples, 793687 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:45:47,505 : INFO : EPOCH 4 - PROGRESS: at 54.10% examples, 792793 words/s, in_qsize 19, out_qsize 3
# 2020-04-01 00:45:48,518 : INFO : EPOCH 4 - PROGRESS: at 56.88% examples, 791854 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:45:49,518 : INFO : EPOCH 4 - PROGRESS: at 59.62% examples, 791957 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:45:50,524 : INFO : EPOCH 4 - PROGRESS: at 62.27% examples, 791135 words/s, in_qsize 20, out_qsize 1
# ...
# 2020-04-01 00:48:02,083 : INFO : EPOCH 8 - PROGRESS: at 4.99% examples, 765485 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:03,092 : INFO : EPOCH 8 - PROGRESS: at 7.61% examples, 781040 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:04,118 : INFO : EPOCH 8 - PROGRESS: at 9.92% examples, 781783 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:05,121 : INFO : EPOCH 8 - PROGRESS: at 11.91% examples, 771871 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:48:06,137 : INFO : EPOCH 8 - PROGRESS: at 14.30% examples, 780164 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:48:07,145 : INFO : EPOCH 8 - PROGRESS: at 16.72% examples, 788435 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:08,152 : INFO : EPOCH 8 - PROGRESS: at 18.87% examples, 787197 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:09,164 : INFO : EPOCH 8 - PROGRESS: at 20.80% examples, 784605 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:10,178 : INFO : EPOCH 8 - PROGRESS: at 23.25% examples, 787529 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:11,184 : INFO : EPOCH 8 - PROGRESS: at 25.60% examples, 787447 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:12,208 : INFO : EPOCH 8 - PROGRESS: at 28.58% examples, 787784 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:13,214 : INFO : EPOCH 8 - PROGRESS: at 31.50% examples, 788368 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:14,222 : INFO : EPOCH 8 - PROGRESS: at 34.20% examples, 788286 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:48:15,225 : INFO : EPOCH 8 - PROGRESS: at 36.93% examples, 787524 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:16,235 : INFO : EPOCH 8 - PROGRESS: at 39.82% examples, 789112 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:17,246 : INFO : EPOCH 8 - PROGRESS: at 42.71% examples, 788787 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 00:48:18,255 : INFO : EPOCH 8 - PROGRESS: at 45.66% examples, 788637 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:19,273 : INFO : EPOCH 8 - PROGRESS: at 48.33% examples, 787721 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:20,294 : INFO : EPOCH 8 - PROGRESS: at 51.13% examples, 787476 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:21,317 : INFO : EPOCH 8 - PROGRESS: at 53.73% examples, 787464 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:22,321 : INFO : EPOCH 8 - PROGRESS: at 56.54% examples, 787705 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:23,329 : INFO : EPOCH 8 - PROGRESS: at 59.25% examples, 787392 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:24,337 : INFO : EPOCH 8 - PROGRESS: at 62.04% examples, 788156 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:48:25,362 : INFO : EPOCH 8 - PROGRESS: at 65.01% examples, 787551 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:26,381 : INFO : EPOCH 8 - PROGRESS: at 67.68% examples, 788138 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:48:27,416 : INFO : EPOCH 8 - PROGRESS: at 70.28% examples, 787775 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:48:28,432 : INFO : EPOCH 8 - PROGRESS: at 73.13% examples, 789053 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:29,453 : INFO : EPOCH 8 - PROGRESS: at 75.82% examples, 789123 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:30,461 : INFO : EPOCH 8 - PROGRESS: at 78.29% examples, 789206 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:31,463 : INFO : EPOCH 8 - PROGRESS: at 80.92% examples, 789692 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:32,469 : INFO : EPOCH 8 - PROGRESS: at 83.55% examples, 789428 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:48:33,469 : INFO : EPOCH 8 - PROGRESS: at 86.07% examples, 789210 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:34,481 : INFO : EPOCH 8 - PROGRESS: at 88.96% examples, 789092 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:35,483 : INFO : EPOCH 8 - PROGRESS: at 91.82% examples, 790032 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:36,507 : INFO : EPOCH 8 - PROGRESS: at 94.49% examples, 789422 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:37,529 : INFO : EPOCH 8 - PROGRESS: at 97.26% examples, 789252 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:48:38,435 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:48:38,457 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:48:38,460 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:48:38,462 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:48:38,484 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:48:38,487 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:48:38,488 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:48:38,489 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:48:38,491 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:48:38,506 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:48:38,508 : INFO : EPOCH - 8 : training on 41519358 raw words (30350534 effective words) took 38.4s, 789690 effective words/s
# 2020-04-01 00:48:39,524 : INFO : EPOCH 9 - PROGRESS: at 2.43% examples, 767856 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:40,547 : INFO : EPOCH 9 - PROGRESS: at 5.17% examples, 786460 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:41,568 : INFO : EPOCH 9 - PROGRESS: at 7.77% examples, 789238 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:42,584 : INFO : EPOCH 9 - PROGRESS: at 10.09% examples, 790028 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:48:43,585 : INFO : EPOCH 9 - PROGRESS: at 12.19% examples, 792885 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:44,592 : INFO : EPOCH 9 - PROGRESS: at 14.56% examples, 793017 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:45,597 : INFO : EPOCH 9 - PROGRESS: at 16.85% examples, 793585 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:46,615 : INFO : EPOCH 9 - PROGRESS: at 18.98% examples, 792420 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:47,617 : INFO : EPOCH 9 - PROGRESS: at 20.98% examples, 791871 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:48,634 : INFO : EPOCH 9 - PROGRESS: at 23.43% examples, 793749 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:48:49,650 : INFO : EPOCH 9 - PROGRESS: at 25.94% examples, 794345 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:50,666 : INFO : EPOCH 9 - PROGRESS: at 28.88% examples, 793312 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:48:51,668 : INFO : EPOCH 9 - PROGRESS: at 31.76% examples, 792657 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:52,691 : INFO : EPOCH 9 - PROGRESS: at 34.48% examples, 791953 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:48:53,705 : INFO : EPOCH 9 - PROGRESS: at 37.30% examples, 792790 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:54,708 : INFO : EPOCH 9 - PROGRESS: at 40.16% examples, 792606 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:55,725 : INFO : EPOCH 9 - PROGRESS: at 43.01% examples, 791797 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:56,740 : INFO : EPOCH 9 - PROGRESS: at 45.97% examples, 791638 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:48:57,744 : INFO : EPOCH 9 - PROGRESS: at 48.79% examples, 793004 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:58,761 : INFO : EPOCH 9 - PROGRESS: at 51.51% examples, 791853 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:48:59,779 : INFO : EPOCH 9 - PROGRESS: at 54.05% examples, 791213 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:00,786 : INFO : EPOCH 9 - PROGRESS: at 56.85% examples, 790868 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:01,799 : INFO : EPOCH 9 - PROGRESS: at 59.55% examples, 789922 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:49:02,800 : INFO : EPOCH 9 - PROGRESS: at 62.25% examples, 790191 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:03,813 : INFO : EPOCH 9 - PROGRESS: at 65.19% examples, 789902 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 00:49:04,836 : INFO : EPOCH 9 - PROGRESS: at 67.91% examples, 790262 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:49:05,864 : INFO : EPOCH 9 - PROGRESS: at 70.59% examples, 791069 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:49:06,864 : INFO : EPOCH 9 - PROGRESS: at 73.39% examples, 791620 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:49:07,875 : INFO : EPOCH 9 - PROGRESS: at 76.01% examples, 791876 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:08,880 : INFO : EPOCH 9 - PROGRESS: at 78.50% examples, 791721 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:09,890 : INFO : EPOCH 9 - PROGRESS: at 81.07% examples, 791650 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:10,913 : INFO : EPOCH 9 - PROGRESS: at 83.81% examples, 791808 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:11,941 : INFO : EPOCH 9 - PROGRESS: at 86.50% examples, 791965 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:49:12,964 : INFO : EPOCH 9 - PROGRESS: at 89.36% examples, 791508 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:13,983 : INFO : EPOCH 9 - PROGRESS: at 92.21% examples, 791599 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:49:15,007 : INFO : EPOCH 9 - PROGRESS: at 94.94% examples, 791729 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:49:16,009 : INFO : EPOCH 9 - PROGRESS: at 97.61% examples, 791305 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:49:16,767 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:49:16,795 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:49:16,797 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:49:16,801 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:49:16,818 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:49:16,824 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:49:16,827 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:49:16,828 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:49:16,839 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:49:16,842 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:49:16,844 : INFO : EPOCH - 9 : training on 41519358 raw words (30349119 effective words) took 38.3s, 791870 effective words/s
# 2020-04-01 00:49:17,867 : INFO : EPOCH 10 - PROGRESS: at 2.41% examples, 755938 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:49:18,872 : INFO : EPOCH 10 - PROGRESS: at 5.12% examples, 783732 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:19,901 : INFO : EPOCH 10 - PROGRESS: at 7.73% examples, 785525 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:49:20,927 : INFO : EPOCH 10 - PROGRESS: at 10.03% examples, 785286 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:49:21,934 : INFO : EPOCH 10 - PROGRESS: at 12.19% examples, 790915 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:22,938 : INFO : EPOCH 10 - PROGRESS: at 14.53% examples, 789368 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:49:23,938 : INFO : EPOCH 10 - PROGRESS: at 16.74% examples, 787951 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:49:24,939 : INFO : EPOCH 10 - PROGRESS: at 18.87% examples, 787371 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:25,942 : INFO : EPOCH 10 - PROGRESS: at 20.80% examples, 784896 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:26,953 : INFO : EPOCH 10 - PROGRESS: at 23.18% examples, 785087 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:49:27,964 : INFO : EPOCH 10 - PROGRESS: at 25.50% examples, 784835 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:28,972 : INFO : EPOCH 10 - PROGRESS: at 28.46% examples, 785800 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:49:29,993 : INFO : EPOCH 10 - PROGRESS: at 31.29% examples, 783979 words/s, in_qsize 19, out_qsize 2
# 2020-04-01 00:49:30,994 : INFO : EPOCH 10 - PROGRESS: at 34.04% examples, 785649 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:32,009 : INFO : EPOCH 10 - PROGRESS: at 36.84% examples, 785438 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:33,014 : INFO : EPOCH 10 - PROGRESS: at 39.60% examples, 785206 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:34,024 : INFO : EPOCH 10 - PROGRESS: at 42.50% examples, 785155 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:49:35,027 : INFO : EPOCH 10 - PROGRESS: at 45.51% examples, 786207 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:36,027 : INFO : EPOCH 10 - PROGRESS: at 48.24% examples, 787278 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:37,040 : INFO : EPOCH 10 - PROGRESS: at 51.06% examples, 787745 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 00:49:38,054 : INFO : EPOCH 10 - PROGRESS: at 53.57% examples, 787008 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:49:39,059 : INFO : EPOCH 10 - PROGRESS: at 56.39% examples, 787165 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:49:40,084 : INFO : EPOCH 10 - PROGRESS: at 59.24% examples, 787923 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:41,086 : INFO : EPOCH 10 - PROGRESS: at 61.91% examples, 787679 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:42,089 : INFO : EPOCH 10 - PROGRESS: at 64.89% examples, 787777 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:43,089 : INFO : EPOCH 10 - PROGRESS: at 67.43% examples, 787500 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:49:44,118 : INFO : EPOCH 10 - PROGRESS: at 70.09% examples, 787916 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:45,118 : INFO : EPOCH 10 - PROGRESS: at 72.81% examples, 788378 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:46,122 : INFO : EPOCH 10 - PROGRESS: at 75.44% examples, 787925 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:47,124 : INFO : EPOCH 10 - PROGRESS: at 77.95% examples, 788652 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:48,125 : INFO : EPOCH 10 - PROGRESS: at 80.56% examples, 788984 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:49,129 : INFO : EPOCH 10 - PROGRESS: at 83.15% examples, 788302 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:49:50,132 : INFO : EPOCH 10 - PROGRESS: at 85.64% examples, 788282 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:51,136 : INFO : EPOCH 10 - PROGRESS: at 88.46% examples, 787916 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 00:49:52,145 : INFO : EPOCH 10 - PROGRESS: at 91.23% examples, 787691 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 00:49:53,147 : INFO : EPOCH 10 - PROGRESS: at 93.95% examples, 788005 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 00:49:54,173 : INFO : EPOCH 10 - PROGRESS: at 96.68% examples, 787829 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 00:49:55,193 : INFO : EPOCH 10 - PROGRESS: at 99.44% examples, 787565 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 00:49:55,285 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 00:49:55,294 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 00:49:55,312 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 00:49:55,315 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 00:49:55,339 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 00:49:55,341 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 00:49:55,348 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 00:49:55,351 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 00:49:55,358 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 00:49:55,361 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 00:49:55,363 : INFO : EPOCH - 10 : training on 41519358 raw words (30347166 effective words) took 38.5s, 788081 effective words/s
# 2020-04-01 00:49:55,364 : INFO : training on a 415193580 raw words (303493742 effective words) took 384.6s, 789184 effective words/s
# (303493742, 415193580)

# %% [markdown]
# ## Now, let's look at some output
# This first example shows a simple case of looking up words similar to the word `dirty`. All we need to do here is to call the `most_similar` function and provide the word `dirty` as the positive example. This returns the top 10 similar words.

# %%
w1 = "dirty"
model.wv.most_similar (positive=w1)
# Out:
# 2020-04-01 00:49:55,572 : INFO : precomputing L2-norms of word weight vectors
# [('filthy', 0.8709099888801575),
#  ('unclean', 0.7770944833755493),
#  ('stained', 0.7743816375732422),
#  ('smelly', 0.7617081999778748),
#  ('grubby', 0.7419587969779968),
#  ('dusty', 0.7398197650909424),
#  ('mouldy', 0.7275347709655762),
#  ('gross', 0.7253711819648743),
#  ('dingy', 0.7180582284927368),
#  ('disgusting', 0.7075618505477905)]

# %% [markdown]
# That looks pretty good, right? Let's look at a few more. Let's look at similarity for `polite`, `france` and `shocked`.

# %%
# look up top 6 words similar to 'polite'
w1 = ["polite"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('courteous', 0.9214778542518616),
#  ('friendly', 0.830007791519165),
#  ('cordial', 0.8248772621154785),
#  ('curteous', 0.7940142750740051),
#  ('professional', 0.7909098863601685),
#  ('attentive', 0.7769151926040649)]

# %%
# look up top 6 words similar to 'france'
w1 = ["france"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('germany', 0.6802625060081482),
#  ('canada', 0.6679942011833191),
#  ('hawaii', 0.6256870627403259),
#  ('spain', 0.6198669672012329),
#  ('austria', 0.6052717566490173),
#  ('england', 0.5947839021682739)]

# %%
# look up top 6 words similar to 'shocked'
w1 = ["shocked"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('astonished', 0.8016294240951538),
#  ('amazed', 0.8011924028396606),
#  ('horrified', 0.7967040538787842),
#  ('dismayed', 0.7663664221763611),
#  ('stunned', 0.7438201308250427),
#  ('surprised', 0.7419900894165039)]

# %% [markdown]
# That's, nice. You can even specify several positive examples to get things that are related in the provided context and provide negative examples to say what should not be considered as related. In the example below we are asking for all items that *relate to bed* only:

# %%
# get everything related to stuff on the bed
w1 = ["bed",'sheet','pillow']
w2 = ['couch']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# [('duvet', 0.7079329490661621),
#  ('blanket', 0.6912814378738403),
#  ('quilt', 0.6884598731994629),
#  ('mattress', 0.6791106462478638),
#  ('matress', 0.6768374443054199),
#  ('sheets', 0.6547210216522217),
#  ('pillowcases', 0.6338222026824951),
#  ('foam', 0.6306774616241455),
#  ('pillows', 0.6271767616271973),
#  ('pillowcase', 0.6258694529533386)]

# %% [markdown]
# ### Similarity between two words in the vocabulary

# %% [markdown]
# You can even use the Word2Vec model to return the similarity between two words that are present in the vocabulary.

# %%
# similarity between two different words
model.wv.similarity(w1="dirty",w2="smelly")
# Out:
# 0.7617082

# %%
# similarity between two identical words
model.wv.similarity(w1="dirty",w2="dirty")
# Out:
# 1.0

# %%
# similarity between two unrelated words
model.wv.similarity(w1="dirty",w2="clean")
# Out:
# 0.26143655

# %% [markdown]
# Under the hood, the above three snippets computes the cosine similarity between the two specified words using word vectors of each. From the scores, it makes sense that `dirty` is highly similar to `smelly` but `dirty` is dissimilar to `clean`. If you do a similarity between two identical words, the score will be 1.0 as the range of the cosine similarity score will always be between [0.0-1.0]. You can read more about cosine similarity scoring [here](https://en.wikipedia.org/wiki/Cosine_similarity).

# %% [markdown]
# ### Find the odd one out
# You can even use Word2Vec to find odd items given a list of items.

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# C:\Users\bruno\Anaconda3\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'france'

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["bed","pillow","duvet","shower"])
# Out:
# 'shower'

# %% [markdown]
# ## Understanding some of the parameters
# To train the model earlier, we had to set some parameters. Now, let's try to understand what some of them mean. For reference, this is the command that we used to train the model.
#
# ```
# model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
# ```
#
# ### `size`
# The size of the dense vector to represent each token or word. If you have very limited data, then size should be a much smaller value. If you have lots of data, its good to experiment with various sizes. A value of 100-150 has worked well for me.
#
# ### `window`
# The maximum distance between the target word and its neighboring word. If your neighbor's position is greater than the maximum window width to the left and the right, then, some neighbors are not considered as being related to the target word. In theory, a smaller window should give you terms that are more related. If you have lots of data, then the window size should not matter too much, as long as its a decent sized window.
#
# ### `min_count`
# Minimium frequency count of words. The model would ignore words that do not statisfy the `min_count`. Extremely infrequent words are usually unimportant, so its best to get rid of those. Unless your dataset is really tiny, this does not really affect the model.
#
# ### `workers`
# How many threads to use behind the scenes?

# %% [markdown]
# ## When should you use Word2Vec?
#
# There are many application scenarios for Word2Vec. Imagine if you need to build a sentiment lexicon. Training a Word2Vec model on large amounts of user reviews helps you achieve that. You have a lexicon for not just sentiment, but for most words in the vocabulary.
#
# Beyond, raw unstructured text data, you could also use Word2Vec for more structured data. For example, if you had tags for a million stackoverflow questions and answers, you could find tags that are related to a given tag and recommend the related ones for exploration. You can do this by treating each set of co-occuring tags as a "sentence" and train a Word2Vec model on this data. Granted, you still need a large number of examples to make it work.
