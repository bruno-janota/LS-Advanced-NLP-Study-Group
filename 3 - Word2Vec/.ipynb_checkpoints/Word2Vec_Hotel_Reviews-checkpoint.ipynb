# %% [markdown]
# # Getting started with Word2Vec in Gensim and making it work!
#
# The idea behind Word2Vec is pretty simple. We are making and assumption that you can tell the meaning of a word by the company it keeps. This is analogous to the saying *show me your friends, and I'll tell who you are*. So if you have two words that have very similar neighbors (i.e. the usage context is about the same), then these words are probably quite similar in meaning or are at least highly related. For example, the words `shocked`,`appalled` and `astonished` are typically used in a similar context.
#
# In this tutorial, you will learn how to use the Gensim implementation of Word2Vec and actually get it to work! I have heard a lot of complaints about poor performance etc, but its really a combination of two things, (1) your input data and (2) your parameter settings. Note that the training algorithms in this package were ported from the [original Word2Vec implementation by Google](https://arxiv.org/pdf/1301.3781.pdf) and extended with additional functionality.

# %% [markdown]
# ### Imports and logging
#
# First, we start with our imports and get logging established:

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ### Dataset
# Next, is our dataset. The secret to getting Word2Vec really working for you is to have lots and lots of text data. In this case I am going to use data from the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset. This dataset has full user reviews of cars and hotels. I have specifically concatenated all of the hotel reviews into one big file which is about 97MB compressed and 229MB uncompressed. We will use the compressed file for this tutorial. Each line in this file represents a hotel review. You can download the OpinRank Word2Vec dataset here.
#
# To avoid confusion, while gensim’s word2vec tutorial says that you need to pass it a sequence of sentences as its input, you can always pass it a whole review as a sentence (i.e. a much larger size of text), and it should not make much of a difference.
#
# Now, let's take a closer look at this data below by printing the first line. You can see that this is a pretty hefty review.

# %%
data_file="./data/reviews_data.txt.gz"

with gzip.open('./data/reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in Beijing, then you will be ok.I chose to have some breakfast in the hotel, which was really tasty and there was a good selection of dishes. There are a couple of computers to use in the communal area, as well as a pool table. There is also a small swimming pool and a gym area.I would definitely stay in this hotel again, but only if I did not plan to travel to central Beijing, as it can take a long time. The location is ok if you plan to do a lot of shopping, as there is a big shopping centre just few minutes away from the hotel and there are plenty of eating options around, including restaurants that serve a dog meat!\t\r\n"

# %% [markdown]
# ### Read files into a list
# Now that we've had a sneak peak of our dataset, we can read it into a list so that we can pass this on to the Word2Vec model. Notice in the code below, that I am directly reading the
# compressed file. I'm also doing a mild pre-processing of the reviews using `gensim.utils.simple_preprocess (line)`. This does some basic pre-processing such as tokenization, lowercasing, etc and returns back a list of tokens (words). Documentation of this pre-processing method can be found on the official [Gensim documentation site](https://radimrehurek.com/gensim/utils.html).

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open(input_file, 'rb') as f:
        for i, line in enumerate(f): 

            if (i%10000==0):
                logging.info("read {0} reviews".format(i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess(line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list(read_input(data_file))
logging.info ("Done reading data file")
# Out:
# 2020-04-01 00:38:23,061 : INFO : reading file reviews_data.txt.gz...this may take a while
# 2020-04-01 00:38:23,069 : INFO : read 0 reviews
# 2020-04-01 00:38:25,770 : INFO : read 10000 reviews
# 2020-04-01 00:38:28,682 : INFO : read 20000 reviews
# 2020-04-01 00:38:32,195 : INFO : read 30000 reviews
# 2020-04-01 00:38:35,394 : INFO : read 40000 reviews
# 2020-04-01 00:38:39,075 : INFO : read 50000 reviews
# 2020-04-01 00:38:42,877 : INFO : read 60000 reviews
# 2020-04-01 00:38:45,686 : INFO : read 70000 reviews
# 2020-04-01 00:38:48,097 : INFO : read 80000 reviews
# 2020-04-01 00:38:50,734 : INFO : read 90000 reviews
# 2020-04-01 00:38:53,260 : INFO : read 100000 reviews
# 2020-04-01 00:38:56,064 : INFO : read 110000 reviews
# 2020-04-01 00:38:58,919 : INFO : read 120000 reviews
# 2020-04-01 00:39:01,593 : INFO : read 130000 reviews
# 2020-04-01 00:39:04,271 : INFO : read 140000 reviews
# 2020-04-01 00:39:06,877 : INFO : read 150000 reviews
# 2020-04-01 00:39:10,757 : INFO : read 160000 reviews
# 2020-04-01 00:39:15,198 : INFO : read 170000 reviews
# 2020-04-01 00:39:18,274 : INFO : read 180000 reviews
# 2020-04-01 00:39:20,953 : INFO : read 190000 reviews
# 2020-04-01 00:39:23,953 : INFO : read 200000 reviews
# 2020-04-01 00:39:27,594 : INFO : read 210000 reviews
# 2020-04-01 00:39:30,422 : INFO : read 220000 reviews
# 2020-04-01 00:39:33,121 : INFO : read 230000 reviews
# 2020-04-01 00:39:35,895 : INFO : read 240000 reviews
# 2020-04-01 00:39:40,301 : INFO : read 250000 reviews
# 2020-04-01 00:39:42,683 : INFO : Done reading data file

# %% [markdown]
# ## Training the Word2Vec model
#
# Training the model is fairly straightforward. You just instantiate Word2Vec and pass the reviews that we read in the previous step (the `documents`). So, we are essentially passing on a list of lists. Where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary. And by vocabulary, I mean a set of unique words.
#
# After building the vocabulary, we just need to call `train(...)` to start training the Word2Vec model. Training on the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset takes about 10 minutes so please be patient while running your code on this dataset.
#
# Behind the scenes we are actually training a simple neural network with a single hidden layer. But, we are actually not going to use the neural network after training. Instead, the goal is to learn the weights of the hidden layer. These weights are essentially the word vectors that we’re trying to learn.

# %%
model = gensim.models.Word2Vec(documents, size=150, window=10, min_count=250, workers=10)
model.train(documents, total_examples=len(documents), epochs=10)
# Out:
# 2020-04-01 22:43:43,514 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2020-04-01 22:43:43,532 : INFO : collecting all words and their counts
# 2020-04-01 22:43:43,535 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-01 22:43:45,132 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2020-04-01 22:43:46,828 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2020-04-01 22:43:48,746 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2020-04-01 22:43:50,818 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2020-04-01 22:43:52,550 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2020-04-01 22:43:54,109 : INFO : PROGRESS: at sentence #60000, processed 11013726 words, keeping 76786 word types
# 2020-04-01 22:43:55,434 : INFO : PROGRESS: at sentence #70000, processed 12637528 words, keeping 83199 word types
# 2020-04-01 22:43:56,334 : INFO : PROGRESS: at sentence #80000, processed 14099754 words, keeping 88459 word types
# 2020-04-01 22:43:57,264 : INFO : PROGRESS: at sentence #90000, processed 15662152 words, keeping 93357 word types
# 2020-04-01 22:43:57,759 : INFO : PROGRESS: at sentence #100000, processed 17164490 words, keeping 97886 word types
# 2020-04-01 22:43:58,310 : INFO : PROGRESS: at sentence #110000, processed 18652295 words, keeping 102132 word types
# 2020-04-01 22:43:58,743 : INFO : PROGRESS: at sentence #120000, processed 20152532 words, keeping 105923 word types
# 2020-04-01 22:43:59,435 : INFO : PROGRESS: at sentence #130000, processed 21684333 words, keeping 110104 word types
# 2020-04-01 22:44:00,029 : INFO : PROGRESS: at sentence #140000, processed 23330209 words, keeping 114108 word types
# 2020-04-01 22:44:00,517 : INFO : PROGRESS: at sentence #150000, processed 24838757 words, keeping 118174 word types
# 2020-04-01 22:44:01,107 : INFO : PROGRESS: at sentence #160000, processed 26390913 words, keeping 118670 word types
# 2020-04-01 22:44:01,518 : INFO : PROGRESS: at sentence #170000, processed 27913919 words, keeping 123356 word types
# 2020-04-01 22:44:01,974 : INFO : PROGRESS: at sentence #180000, processed 29535615 words, keeping 126748 word types
# 2020-04-01 22:44:02,428 : INFO : PROGRESS: at sentence #190000, processed 31096462 words, keeping 129847 word types
# 2020-04-01 22:44:02,920 : INFO : PROGRESS: at sentence #200000, processed 32805274 words, keeping 133255 word types
# 2020-04-01 22:44:03,388 : INFO : PROGRESS: at sentence #210000, processed 34434201 words, keeping 136364 word types
# 2020-04-01 22:44:03,839 : INFO : PROGRESS: at sentence #220000, processed 36083485 words, keeping 139418 word types
# 2020-04-01 22:44:04,274 : INFO : PROGRESS: at sentence #230000, processed 37571765 words, keeping 142399 word types
# 2020-04-01 22:44:04,761 : INFO : PROGRESS: at sentence #240000, processed 39138193 words, keeping 145232 word types
# 2020-04-01 22:44:05,199 : INFO : PROGRESS: at sentence #250000, processed 40695052 words, keeping 147966 word types
# 2020-04-01 22:44:05,451 : INFO : collected 150059 word types from a corpus of 41519358 raw words and 255404 sentences
# 2020-04-01 22:44:05,456 : INFO : Loading a fresh vocabulary
# 2020-04-01 22:44:05,590 : INFO : effective_min_count=250 retains 5532 unique words (3% of original 150059, drops 144527)
# 2020-04-01 22:44:05,592 : INFO : effective_min_count=250 leaves 40178335 word corpus (96% of original 41519358, drops 1341023)
# 2020-04-01 22:44:05,627 : INFO : deleting the raw counts dictionary of 150059 items
# 2020-04-01 22:44:05,634 : INFO : sample=0.001 downsamples 56 most-common words
# 2020-04-01 22:44:05,636 : INFO : downsampling leaves estimated 28923698 word corpus (72.0% of prior 40178335)
# 2020-04-01 22:44:05,686 : INFO : estimated required memory for 5532 words and 150 dimensions: 9404400 bytes
# 2020-04-01 22:44:05,690 : INFO : resetting layer weights
# 2020-04-01 22:44:07,681 : INFO : training model with 10 workers on 5532 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2020-04-01 22:44:08,841 : INFO : EPOCH 1 - PROGRESS: at 2.71% examples, 803475 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:09,846 : INFO : EPOCH 1 - PROGRESS: at 5.69% examples, 830120 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:44:10,875 : INFO : EPOCH 1 - PROGRESS: at 8.27% examples, 804161 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:44:11,877 : INFO : EPOCH 1 - PROGRESS: at 10.14% examples, 761380 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:12,883 : INFO : EPOCH 1 - PROGRESS: at 12.71% examples, 791466 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:44:13,898 : INFO : EPOCH 1 - PROGRESS: at 15.20% examples, 789755 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:14,936 : INFO : EPOCH 1 - PROGRESS: at 17.49% examples, 784629 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:44:15,939 : INFO : EPOCH 1 - PROGRESS: at 19.65% examples, 782913 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:16,977 : INFO : EPOCH 1 - PROGRESS: at 22.34% examples, 789795 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:44:17,980 : INFO : EPOCH 1 - PROGRESS: at 24.64% examples, 795991 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:18,983 : INFO : EPOCH 1 - PROGRESS: at 28.54% examples, 813663 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:19,988 : INFO : EPOCH 1 - PROGRESS: at 32.16% examples, 824858 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:21,009 : INFO : EPOCH 1 - PROGRESS: at 35.50% examples, 832239 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:22,013 : INFO : EPOCH 1 - PROGRESS: at 39.28% examples, 844032 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:23,022 : INFO : EPOCH 1 - PROGRESS: at 42.75% examples, 849024 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:24,023 : INFO : EPOCH 1 - PROGRESS: at 46.54% examples, 858190 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:25,028 : INFO : EPOCH 1 - PROGRESS: at 50.14% examples, 864962 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:26,036 : INFO : EPOCH 1 - PROGRESS: at 53.41% examples, 869628 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:27,050 : INFO : EPOCH 1 - PROGRESS: at 56.90% examples, 872861 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 22:44:28,073 : INFO : EPOCH 1 - PROGRESS: at 60.41% examples, 876651 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:29,074 : INFO : EPOCH 1 - PROGRESS: at 64.11% examples, 881042 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:44:30,075 : INFO : EPOCH 1 - PROGRESS: at 67.34% examples, 882641 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:31,078 : INFO : EPOCH 1 - PROGRESS: at 70.43% examples, 883784 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:32,084 : INFO : EPOCH 1 - PROGRESS: at 73.60% examples, 883375 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:33,089 : INFO : EPOCH 1 - PROGRESS: at 76.44% examples, 882329 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:34,089 : INFO : EPOCH 1 - PROGRESS: at 79.52% examples, 883399 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:35,090 : INFO : EPOCH 1 - PROGRESS: at 82.61% examples, 883848 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:36,109 : INFO : EPOCH 1 - PROGRESS: at 85.33% examples, 880906 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:37,119 : INFO : EPOCH 1 - PROGRESS: at 88.49% examples, 879149 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:38,126 : INFO : EPOCH 1 - PROGRESS: at 91.45% examples, 876617 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:39,149 : INFO : EPOCH 1 - PROGRESS: at 94.46% examples, 874762 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:40,150 : INFO : EPOCH 1 - PROGRESS: at 97.50% examples, 873847 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:40,960 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:44:40,993 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:44:40,995 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:44:41,011 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:44:41,022 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:44:41,024 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:44:41,027 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:44:41,030 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:44:41,031 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:44:41,037 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:44:41,039 : INFO : EPOCH - 1 : training on 41519358 raw words (28921266 effective words) took 33.2s, 870977 effective words/s
# 2020-04-01 22:44:42,054 : INFO : EPOCH 2 - PROGRESS: at 2.46% examples, 739595 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:43,059 : INFO : EPOCH 2 - PROGRESS: at 5.10% examples, 747202 words/s, in_qsize 13, out_qsize 6
# 2020-04-01 22:44:44,070 : INFO : EPOCH 2 - PROGRESS: at 7.91% examples, 774796 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:44:45,071 : INFO : EPOCH 2 - PROGRESS: at 10.27% examples, 778208 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:46,103 : INFO : EPOCH 2 - PROGRESS: at 12.42% examples, 771386 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:47,109 : INFO : EPOCH 2 - PROGRESS: at 14.86% examples, 774165 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:48,136 : INFO : EPOCH 2 - PROGRESS: at 17.13% examples, 768611 words/s, in_qsize 20, out_qsize 4
# 2020-04-01 22:44:49,136 : INFO : EPOCH 2 - PROGRESS: at 19.37% examples, 773347 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:50,137 : INFO : EPOCH 2 - PROGRESS: at 21.80% examples, 773918 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:51,151 : INFO : EPOCH 2 - PROGRESS: at 23.82% examples, 770120 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:52,175 : INFO : EPOCH 2 - PROGRESS: at 26.48% examples, 767700 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:44:53,195 : INFO : EPOCH 2 - PROGRESS: at 29.23% examples, 762538 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:54,196 : INFO : EPOCH 2 - PROGRESS: at 31.82% examples, 755140 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:44:55,198 : INFO : EPOCH 2 - PROGRESS: at 34.50% examples, 755271 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:56,199 : INFO : EPOCH 2 - PROGRESS: at 37.19% examples, 754449 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:44:57,203 : INFO : EPOCH 2 - PROGRESS: at 39.96% examples, 753408 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:44:58,213 : INFO : EPOCH 2 - PROGRESS: at 42.62% examples, 749539 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:44:59,215 : INFO : EPOCH 2 - PROGRESS: at 44.52% examples, 735157 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:00,241 : INFO : EPOCH 2 - PROGRESS: at 47.15% examples, 733407 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:01,249 : INFO : EPOCH 2 - PROGRESS: at 49.61% examples, 729675 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:02,252 : INFO : EPOCH 2 - PROGRESS: at 52.05% examples, 727395 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:03,267 : INFO : EPOCH 2 - PROGRESS: at 54.32% examples, 724222 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:04,306 : INFO : EPOCH 2 - PROGRESS: at 57.14% examples, 724100 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:45:05,324 : INFO : EPOCH 2 - PROGRESS: at 59.97% examples, 726272 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:45:06,337 : INFO : EPOCH 2 - PROGRESS: at 62.72% examples, 727099 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:07,338 : INFO : EPOCH 2 - PROGRESS: at 65.49% examples, 726844 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:08,343 : INFO : EPOCH 2 - PROGRESS: at 67.95% examples, 725758 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:09,347 : INFO : EPOCH 2 - PROGRESS: at 70.32% examples, 725148 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:10,347 : INFO : EPOCH 2 - PROGRESS: at 72.81% examples, 724252 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:11,348 : INFO : EPOCH 2 - PROGRESS: at 75.46% examples, 725156 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:12,356 : INFO : EPOCH 2 - PROGRESS: at 77.82% examples, 725170 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:45:13,372 : INFO : EPOCH 2 - PROGRESS: at 80.35% examples, 725257 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:14,393 : INFO : EPOCH 2 - PROGRESS: at 82.92% examples, 725313 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:15,418 : INFO : EPOCH 2 - PROGRESS: at 85.52% examples, 726438 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:45:16,425 : INFO : EPOCH 2 - PROGRESS: at 88.29% examples, 726606 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:17,430 : INFO : EPOCH 2 - PROGRESS: at 90.98% examples, 726468 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 22:45:18,453 : INFO : EPOCH 2 - PROGRESS: at 93.29% examples, 724253 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:45:19,523 : INFO : EPOCH 2 - PROGRESS: at 95.97% examples, 723298 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:20,529 : INFO : EPOCH 2 - PROGRESS: at 98.67% examples, 723655 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:45:20,921 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:45:20,932 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:45:20,935 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:45:20,937 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:45:20,946 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:45:20,956 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:45:20,968 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:45:20,972 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:45:20,976 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:45:20,979 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:45:20,981 : INFO : EPOCH - 2 : training on 41519358 raw words (28924645 effective words) took 39.9s, 724425 effective words/s
# 2020-04-01 22:45:22,003 : INFO : EPOCH 3 - PROGRESS: at 2.12% examples, 633300 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:23,036 : INFO : EPOCH 3 - PROGRESS: at 4.42% examples, 637229 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:45:24,043 : INFO : EPOCH 3 - PROGRESS: at 6.52% examples, 629865 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:25,059 : INFO : EPOCH 3 - PROGRESS: at 8.66% examples, 629573 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:26,074 : INFO : EPOCH 3 - PROGRESS: at 10.75% examples, 646743 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:45:27,082 : INFO : EPOCH 3 - PROGRESS: at 12.65% examples, 653649 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:28,099 : INFO : EPOCH 3 - PROGRESS: at 14.89% examples, 661114 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:29,101 : INFO : EPOCH 3 - PROGRESS: at 17.03% examples, 666589 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:30,109 : INFO : EPOCH 3 - PROGRESS: at 19.13% examples, 674767 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:31,125 : INFO : EPOCH 3 - PROGRESS: at 21.41% examples, 680618 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:45:32,130 : INFO : EPOCH 3 - PROGRESS: at 23.39% examples, 684415 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:33,131 : INFO : EPOCH 3 - PROGRESS: at 25.60% examples, 685479 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:34,138 : INFO : EPOCH 3 - PROGRESS: at 28.33% examples, 686225 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:35,140 : INFO : EPOCH 3 - PROGRESS: at 31.06% examples, 689217 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:36,142 : INFO : EPOCH 3 - PROGRESS: at 33.82% examples, 693441 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:37,157 : INFO : EPOCH 3 - PROGRESS: at 36.56% examples, 695529 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:38,185 : INFO : EPOCH 3 - PROGRESS: at 39.32% examples, 697182 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:39,188 : INFO : EPOCH 3 - PROGRESS: at 41.97% examples, 696533 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:45:40,199 : INFO : EPOCH 3 - PROGRESS: at 44.76% examples, 698166 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:41,200 : INFO : EPOCH 3 - PROGRESS: at 47.53% examples, 701609 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:42,210 : INFO : EPOCH 3 - PROGRESS: at 50.14% examples, 701200 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:43,226 : INFO : EPOCH 3 - PROGRESS: at 52.69% examples, 702404 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:44,228 : INFO : EPOCH 3 - PROGRESS: at 55.17% examples, 702063 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:45:45,231 : INFO : EPOCH 3 - PROGRESS: at 57.85% examples, 703315 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:46,254 : INFO : EPOCH 3 - PROGRESS: at 60.48% examples, 703432 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:47,264 : INFO : EPOCH 3 - PROGRESS: at 62.70% examples, 699656 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:48,290 : INFO : EPOCH 3 - PROGRESS: at 64.91% examples, 693215 words/s, in_qsize 20, out_qsize 4
# 2020-04-01 22:45:49,317 : INFO : EPOCH 3 - PROGRESS: at 66.85% examples, 688671 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:50,325 : INFO : EPOCH 3 - PROGRESS: at 69.30% examples, 688785 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:51,330 : INFO : EPOCH 3 - PROGRESS: at 71.56% examples, 688051 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:52,356 : INFO : EPOCH 3 - PROGRESS: at 74.11% examples, 687629 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:45:53,358 : INFO : EPOCH 3 - PROGRESS: at 76.33% examples, 687404 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 22:45:54,360 : INFO : EPOCH 3 - PROGRESS: at 78.50% examples, 686421 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:55,393 : INFO : EPOCH 3 - PROGRESS: at 80.86% examples, 686070 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:45:56,434 : INFO : EPOCH 3 - PROGRESS: at 83.52% examples, 687265 words/s, in_qsize 17, out_qsize 4
# 2020-04-01 22:45:57,462 : INFO : EPOCH 3 - PROGRESS: at 86.02% examples, 688432 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:58,489 : INFO : EPOCH 3 - PROGRESS: at 88.22% examples, 684996 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:45:59,506 : INFO : EPOCH 3 - PROGRESS: at 90.87% examples, 685590 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:46:00,509 : INFO : EPOCH 3 - PROGRESS: at 93.38% examples, 686117 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:01,519 : INFO : EPOCH 3 - PROGRESS: at 96.26% examples, 688741 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:02,520 : INFO : EPOCH 3 - PROGRESS: at 98.94% examples, 689660 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:46:02,854 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:46:02,867 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:46:02,882 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:46:02,885 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:46:02,887 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:46:02,896 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:46:02,903 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:46:02,905 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:46:02,911 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:46:02,913 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:46:02,914 : INFO : EPOCH - 3 : training on 41519358 raw words (28926294 effective words) took 41.9s, 690087 effective words/s
# 2020-04-01 22:46:03,949 : INFO : EPOCH 4 - PROGRESS: at 2.25% examples, 667150 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:04,986 : INFO : EPOCH 4 - PROGRESS: at 4.83% examples, 689674 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:05,993 : INFO : EPOCH 4 - PROGRESS: at 7.18% examples, 689483 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:06,993 : INFO : EPOCH 4 - PROGRESS: at 9.54% examples, 701377 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:46:08,001 : INFO : EPOCH 4 - PROGRESS: at 11.47% examples, 698710 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:46:09,018 : INFO : EPOCH 4 - PROGRESS: at 13.63% examples, 701672 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 22:46:10,029 : INFO : EPOCH 4 - PROGRESS: at 15.72% examples, 696558 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:46:11,046 : INFO : EPOCH 4 - PROGRESS: at 17.77% examples, 699749 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:12,049 : INFO : EPOCH 4 - PROGRESS: at 19.55% examples, 692448 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:13,054 : INFO : EPOCH 4 - PROGRESS: at 21.47% examples, 682923 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:14,077 : INFO : EPOCH 4 - PROGRESS: at 23.38% examples, 682989 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:46:15,109 : INFO : EPOCH 4 - PROGRESS: at 25.53% examples, 681303 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:16,136 : INFO : EPOCH 4 - PROGRESS: at 28.23% examples, 680262 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:46:17,138 : INFO : EPOCH 4 - PROGRESS: at 30.98% examples, 684145 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:46:18,140 : INFO : EPOCH 4 - PROGRESS: at 33.64% examples, 686383 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:19,144 : INFO : EPOCH 4 - PROGRESS: at 36.19% examples, 687355 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:46:20,147 : INFO : EPOCH 4 - PROGRESS: at 39.00% examples, 691217 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:21,152 : INFO : EPOCH 4 - PROGRESS: at 41.89% examples, 694157 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:22,167 : INFO : EPOCH 4 - PROGRESS: at 44.81% examples, 697602 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:23,186 : INFO : EPOCH 4 - PROGRESS: at 47.42% examples, 698444 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:24,209 : INFO : EPOCH 4 - PROGRESS: at 50.17% examples, 699338 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:25,223 : INFO : EPOCH 4 - PROGRESS: at 52.67% examples, 700020 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:26,235 : INFO : EPOCH 4 - PROGRESS: at 55.35% examples, 701553 words/s, in_qsize 17, out_qsize 4
# 2020-04-01 22:46:27,248 : INFO : EPOCH 4 - PROGRESS: at 58.17% examples, 704493 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:28,262 : INFO : EPOCH 4 - PROGRESS: at 60.88% examples, 705376 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:29,277 : INFO : EPOCH 4 - PROGRESS: at 63.59% examples, 705773 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:46:30,295 : INFO : EPOCH 4 - PROGRESS: at 66.35% examples, 707453 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:31,303 : INFO : EPOCH 4 - PROGRESS: at 69.02% examples, 708820 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:32,307 : INFO : EPOCH 4 - PROGRESS: at 71.61% examples, 710891 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:33,308 : INFO : EPOCH 4 - PROGRESS: at 74.12% examples, 710047 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:46:34,310 : INFO : EPOCH 4 - PROGRESS: at 76.55% examples, 711044 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:35,346 : INFO : EPOCH 4 - PROGRESS: at 78.80% examples, 709153 words/s, in_qsize 16, out_qsize 6
# 2020-04-01 22:46:36,354 : INFO : EPOCH 4 - PROGRESS: at 81.21% examples, 709033 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:37,358 : INFO : EPOCH 4 - PROGRESS: at 83.86% examples, 710351 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:38,358 : INFO : EPOCH 4 - PROGRESS: at 86.33% examples, 710833 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:46:39,401 : INFO : EPOCH 4 - PROGRESS: at 89.01% examples, 709774 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:46:40,408 : INFO : EPOCH 4 - PROGRESS: at 91.76% examples, 710744 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:41,420 : INFO : EPOCH 4 - PROGRESS: at 94.31% examples, 710654 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:42,431 : INFO : EPOCH 4 - PROGRESS: at 97.07% examples, 711992 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:43,408 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:46:43,435 : INFO : EPOCH 4 - PROGRESS: at 99.82% examples, 712753 words/s, in_qsize 7, out_qsize 3
# 2020-04-01 22:46:43,438 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:46:43,441 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:46:43,455 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:46:43,462 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:46:43,469 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:46:43,474 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:46:43,477 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:46:43,486 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:46:43,496 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:46:43,498 : INFO : EPOCH - 4 : training on 41519358 raw words (28920593 effective words) took 40.6s, 712917 effective words/s
# 2020-04-01 22:46:44,524 : INFO : EPOCH 5 - PROGRESS: at 2.28% examples, 677020 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:46:45,548 : INFO : EPOCH 5 - PROGRESS: at 4.86% examples, 698888 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:46,563 : INFO : EPOCH 5 - PROGRESS: at 7.31% examples, 705022 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:46:47,565 : INFO : EPOCH 5 - PROGRESS: at 9.73% examples, 719363 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:48,575 : INFO : EPOCH 5 - PROGRESS: at 11.81% examples, 726302 words/s, in_qsize 18, out_qsize 2
# 2020-04-01 22:46:49,598 : INFO : EPOCH 5 - PROGRESS: at 13.78% examples, 710567 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:50,605 : INFO : EPOCH 5 - PROGRESS: at 15.96% examples, 710359 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:46:51,641 : INFO : EPOCH 5 - PROGRESS: at 17.98% examples, 706746 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:52,659 : INFO : EPOCH 5 - PROGRESS: at 19.96% examples, 706517 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:53,661 : INFO : EPOCH 5 - PROGRESS: at 22.27% examples, 709431 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:46:54,662 : INFO : EPOCH 5 - PROGRESS: at 24.31% examples, 713304 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:55,679 : INFO : EPOCH 5 - PROGRESS: at 27.01% examples, 713459 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:56,688 : INFO : EPOCH 5 - PROGRESS: at 29.83% examples, 714494 words/s, in_qsize 19, out_qsize 4
# 2020-04-01 22:46:57,701 : INFO : EPOCH 5 - PROGRESS: at 32.68% examples, 716674 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:46:58,775 : INFO : EPOCH 5 - PROGRESS: at 34.73% examples, 704307 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:46:59,780 : INFO : EPOCH 5 - PROGRESS: at 36.95% examples, 698033 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:00,828 : INFO : EPOCH 5 - PROGRESS: at 39.32% examples, 691934 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:01,837 : INFO : EPOCH 5 - PROGRESS: at 42.07% examples, 692799 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:02,863 : INFO : EPOCH 5 - PROGRESS: at 44.49% examples, 689161 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:03,873 : INFO : EPOCH 5 - PROGRESS: at 46.69% examples, 684312 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:04,874 : INFO : EPOCH 5 - PROGRESS: at 48.60% examples, 677015 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:05,890 : INFO : EPOCH 5 - PROGRESS: at 50.82% examples, 673214 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:06,916 : INFO : EPOCH 5 - PROGRESS: at 53.21% examples, 674044 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:07,923 : INFO : EPOCH 5 - PROGRESS: at 55.71% examples, 673652 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:47:08,932 : INFO : EPOCH 5 - PROGRESS: at 58.19% examples, 674144 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:09,938 : INFO : EPOCH 5 - PROGRESS: at 60.66% examples, 674026 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:10,940 : INFO : EPOCH 5 - PROGRESS: at 63.39% examples, 676184 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:11,980 : INFO : EPOCH 5 - PROGRESS: at 65.83% examples, 674695 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 22:47:12,982 : INFO : EPOCH 5 - PROGRESS: at 68.48% examples, 677215 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:13,987 : INFO : EPOCH 5 - PROGRESS: at 70.98% examples, 679783 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:14,999 : INFO : EPOCH 5 - PROGRESS: at 73.77% examples, 681705 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:16,010 : INFO : EPOCH 5 - PROGRESS: at 76.24% examples, 683583 words/s, in_qsize 18, out_qsize 2
# 2020-04-01 22:47:17,023 : INFO : EPOCH 5 - PROGRESS: at 78.75% examples, 685561 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:18,028 : INFO : EPOCH 5 - PROGRESS: at 81.14% examples, 686172 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:19,056 : INFO : EPOCH 5 - PROGRESS: at 83.61% examples, 686107 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:20,070 : INFO : EPOCH 5 - PROGRESS: at 86.09% examples, 687174 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:21,074 : INFO : EPOCH 5 - PROGRESS: at 88.85% examples, 688072 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:22,075 : INFO : EPOCH 5 - PROGRESS: at 91.54% examples, 689185 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:23,102 : INFO : EPOCH 5 - PROGRESS: at 94.19% examples, 690086 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:24,116 : INFO : EPOCH 5 - PROGRESS: at 96.62% examples, 689830 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:25,148 : INFO : EPOCH 5 - PROGRESS: at 99.29% examples, 690196 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:25,334 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:47:25,338 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:47:25,340 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:47:25,347 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:47:25,357 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:47:25,362 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:47:25,364 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:47:25,369 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:47:25,375 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:47:25,383 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:47:25,386 : INFO : EPOCH - 5 : training on 41519358 raw words (28923643 effective words) took 41.9s, 690748 effective words/s
# 2020-04-01 22:47:25,388 : INFO : training on a 207596790 raw words (144616441 effective words) took 197.7s, 731480 effective words/s
# 2020-04-01 22:47:25,414 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-04-01 22:47:25,415 : INFO : training model with 10 workers on 5532 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2020-04-01 22:47:26,433 : INFO : EPOCH 1 - PROGRESS: at 2.24% examples, 669566 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:27,455 : INFO : EPOCH 1 - PROGRESS: at 4.46% examples, 648217 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:28,486 : INFO : EPOCH 1 - PROGRESS: at 6.89% examples, 661137 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:29,495 : INFO : EPOCH 1 - PROGRESS: at 9.17% examples, 670920 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:30,503 : INFO : EPOCH 1 - PROGRESS: at 11.08% examples, 671174 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:31,503 : INFO : EPOCH 1 - PROGRESS: at 13.17% examples, 678388 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:32,512 : INFO : EPOCH 1 - PROGRESS: at 15.47% examples, 687082 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:33,521 : INFO : EPOCH 1 - PROGRESS: at 17.68% examples, 697503 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:34,549 : INFO : EPOCH 1 - PROGRESS: at 19.71% examples, 698999 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:35,563 : INFO : EPOCH 1 - PROGRESS: at 21.98% examples, 700456 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:36,568 : INFO : EPOCH 1 - PROGRESS: at 23.93% examples, 702512 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:47:37,585 : INFO : EPOCH 1 - PROGRESS: at 26.11% examples, 695014 words/s, in_qsize 20, out_qsize 4
# 2020-04-01 22:47:38,603 : INFO : EPOCH 1 - PROGRESS: at 29.02% examples, 698222 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:47:39,615 : INFO : EPOCH 1 - PROGRESS: at 31.76% examples, 698696 words/s, in_qsize 15, out_qsize 3
# 2020-04-01 22:47:40,621 : INFO : EPOCH 1 - PROGRESS: at 34.37% examples, 700950 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:41,653 : INFO : EPOCH 1 - PROGRESS: at 37.08% examples, 702227 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:42,680 : INFO : EPOCH 1 - PROGRESS: at 39.76% examples, 702252 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:43,689 : INFO : EPOCH 1 - PROGRESS: at 42.79% examples, 707062 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:44,723 : INFO : EPOCH 1 - PROGRESS: at 45.71% examples, 708091 words/s, in_qsize 15, out_qsize 4
# 2020-04-01 22:47:45,729 : INFO : EPOCH 1 - PROGRESS: at 48.24% examples, 707816 words/s, in_qsize 18, out_qsize 5
# 2020-04-01 22:47:46,739 : INFO : EPOCH 1 - PROGRESS: at 50.99% examples, 709301 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:47,757 : INFO : EPOCH 1 - PROGRESS: at 53.51% examples, 710356 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:48,760 : INFO : EPOCH 1 - PROGRESS: at 56.30% examples, 712040 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:47:49,764 : INFO : EPOCH 1 - PROGRESS: at 59.07% examples, 714013 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:50,765 : INFO : EPOCH 1 - PROGRESS: at 61.66% examples, 714342 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:51,765 : INFO : EPOCH 1 - PROGRESS: at 64.48% examples, 714159 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 22:47:52,787 : INFO : EPOCH 1 - PROGRESS: at 67.02% examples, 714733 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:47:53,791 : INFO : EPOCH 1 - PROGRESS: at 69.82% examples, 717690 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:54,792 : INFO : EPOCH 1 - PROGRESS: at 72.28% examples, 717982 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:47:55,814 : INFO : EPOCH 1 - PROGRESS: at 74.92% examples, 717653 words/s, in_qsize 20, out_qsize 4
# 2020-04-01 22:47:56,826 : INFO : EPOCH 1 - PROGRESS: at 77.27% examples, 717606 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:47:57,833 : INFO : EPOCH 1 - PROGRESS: at 79.71% examples, 717653 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:47:58,849 : INFO : EPOCH 1 - PROGRESS: at 82.26% examples, 718093 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:47:59,849 : INFO : EPOCH 1 - PROGRESS: at 84.65% examples, 717998 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:48:00,865 : INFO : EPOCH 1 - PROGRESS: at 87.30% examples, 717950 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:01,870 : INFO : EPOCH 1 - PROGRESS: at 89.82% examples, 716733 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:02,887 : INFO : EPOCH 1 - PROGRESS: at 92.36% examples, 715502 words/s, in_qsize 20, out_qsize 5
# 2020-04-01 22:48:03,888 : INFO : EPOCH 1 - PROGRESS: at 94.95% examples, 716210 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:04,895 : INFO : EPOCH 1 - PROGRESS: at 97.66% examples, 717062 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:05,687 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:48:05,718 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:48:05,722 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:48:05,724 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:48:05,736 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:48:05,739 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:48:05,740 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:48:05,748 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:48:05,751 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:48:05,770 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:48:05,772 : INFO : EPOCH - 1 : training on 41519358 raw words (28925008 effective words) took 40.3s, 717007 effective words/s
# 2020-04-01 22:48:06,811 : INFO : EPOCH 2 - PROGRESS: at 2.26% examples, 662086 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:48:07,814 : INFO : EPOCH 2 - PROGRESS: at 4.67% examples, 678199 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:48:08,824 : INFO : EPOCH 2 - PROGRESS: at 7.22% examples, 699683 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:48:09,835 : INFO : EPOCH 2 - PROGRESS: at 9.60% examples, 708651 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 22:48:10,837 : INFO : EPOCH 2 - PROGRESS: at 11.51% examples, 703881 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:48:11,852 : INFO : EPOCH 2 - PROGRESS: at 13.74% examples, 709635 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:12,855 : INFO : EPOCH 2 - PROGRESS: at 15.87% examples, 708019 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:13,876 : INFO : EPOCH 2 - PROGRESS: at 17.98% examples, 710280 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:14,915 : INFO : EPOCH 2 - PROGRESS: at 20.03% examples, 710911 words/s, in_qsize 15, out_qsize 4
# 2020-04-01 22:48:15,927 : INFO : EPOCH 2 - PROGRESS: at 22.28% examples, 710143 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:16,928 : INFO : EPOCH 2 - PROGRESS: at 24.13% examples, 708457 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:17,946 : INFO : EPOCH 2 - PROGRESS: at 26.68% examples, 706696 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:18,981 : INFO : EPOCH 2 - PROGRESS: at 29.56% examples, 708477 words/s, in_qsize 19, out_qsize 5
# 2020-04-01 22:48:19,993 : INFO : EPOCH 2 - PROGRESS: at 32.50% examples, 712057 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:21,024 : INFO : EPOCH 2 - PROGRESS: at 34.98% examples, 710157 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:48:22,025 : INFO : EPOCH 2 - PROGRESS: at 37.45% examples, 707858 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:23,027 : INFO : EPOCH 2 - PROGRESS: at 39.98% examples, 706171 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:24,037 : INFO : EPOCH 2 - PROGRESS: at 42.53% examples, 703272 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:25,061 : INFO : EPOCH 2 - PROGRESS: at 45.36% examples, 703771 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:26,068 : INFO : EPOCH 2 - PROGRESS: at 47.85% examples, 702977 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:27,089 : INFO : EPOCH 2 - PROGRESS: at 50.39% examples, 701744 words/s, in_qsize 19, out_qsize 2
# 2020-04-01 22:48:28,107 : INFO : EPOCH 2 - PROGRESS: at 52.80% examples, 700952 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:29,127 : INFO : EPOCH 2 - PROGRESS: at 55.29% examples, 699890 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:30,171 : INFO : EPOCH 2 - PROGRESS: at 57.98% examples, 700279 words/s, in_qsize 19, out_qsize 4
# 2020-04-01 22:48:31,180 : INFO : EPOCH 2 - PROGRESS: at 60.74% examples, 702274 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:32,192 : INFO : EPOCH 2 - PROGRESS: at 63.39% examples, 702387 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:33,236 : INFO : EPOCH 2 - PROGRESS: at 66.07% examples, 702507 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:48:34,252 : INFO : EPOCH 2 - PROGRESS: at 68.85% examples, 704751 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:35,265 : INFO : EPOCH 2 - PROGRESS: at 71.44% examples, 706769 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:36,265 : INFO : EPOCH 2 - PROGRESS: at 74.13% examples, 707660 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:37,272 : INFO : EPOCH 2 - PROGRESS: at 76.53% examples, 708404 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:38,339 : INFO : EPOCH 2 - PROGRESS: at 78.95% examples, 707649 words/s, in_qsize 15, out_qsize 4
# 2020-04-01 22:48:39,358 : INFO : EPOCH 2 - PROGRESS: at 81.48% examples, 708363 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:40,378 : INFO : EPOCH 2 - PROGRESS: at 84.19% examples, 709734 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:48:41,379 : INFO : EPOCH 2 - PROGRESS: at 86.58% examples, 709306 words/s, in_qsize 17, out_qsize 5
# 2020-04-01 22:48:42,422 : INFO : EPOCH 2 - PROGRESS: at 89.33% examples, 709055 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:43,430 : INFO : EPOCH 2 - PROGRESS: at 92.04% examples, 709694 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:44,436 : INFO : EPOCH 2 - PROGRESS: at 94.54% examples, 709364 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:45,441 : INFO : EPOCH 2 - PROGRESS: at 97.15% examples, 709784 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:46,456 : INFO : EPOCH 2 - PROGRESS: at 99.74% examples, 709420 words/s, in_qsize 11, out_qsize 0
# 2020-04-01 22:48:46,471 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:48:46,479 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:48:46,481 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:48:46,485 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:48:46,490 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:48:46,498 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:48:46,508 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:48:46,520 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:48:46,523 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:48:46,524 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:48:46,525 : INFO : EPOCH - 2 : training on 41519358 raw words (28923313 effective words) took 40.7s, 709971 effective words/s
# 2020-04-01 22:48:47,565 : INFO : EPOCH 3 - PROGRESS: at 2.24% examples, 656809 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:48,569 : INFO : EPOCH 3 - PROGRESS: at 4.68% examples, 678529 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:49,576 : INFO : EPOCH 3 - PROGRESS: at 7.14% examples, 691277 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:50,585 : INFO : EPOCH 3 - PROGRESS: at 9.56% examples, 706516 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:48:51,593 : INFO : EPOCH 3 - PROGRESS: at 11.52% examples, 705388 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:52,603 : INFO : EPOCH 3 - PROGRESS: at 13.75% examples, 710299 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:53,628 : INFO : EPOCH 3 - PROGRESS: at 15.93% examples, 709248 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:54,635 : INFO : EPOCH 3 - PROGRESS: at 17.85% examples, 704155 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:48:55,657 : INFO : EPOCH 3 - PROGRESS: at 19.85% examples, 704470 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:48:56,677 : INFO : EPOCH 3 - PROGRESS: at 22.10% examples, 704289 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:48:57,709 : INFO : EPOCH 3 - PROGRESS: at 24.04% examples, 704240 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:48:58,733 : INFO : EPOCH 3 - PROGRESS: at 26.57% examples, 701927 words/s, in_qsize 19, out_qsize 4
# 2020-04-01 22:48:59,734 : INFO : EPOCH 3 - PROGRESS: at 29.23% examples, 701675 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:00,739 : INFO : EPOCH 3 - PROGRESS: at 31.97% examples, 701780 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:49:01,743 : INFO : EPOCH 3 - PROGRESS: at 34.57% examples, 703973 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:02,745 : INFO : EPOCH 3 - PROGRESS: at 37.21% examples, 705484 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:49:03,776 : INFO : EPOCH 3 - PROGRESS: at 39.71% examples, 701964 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 22:49:04,777 : INFO : EPOCH 3 - PROGRESS: at 42.20% examples, 698103 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 22:49:05,799 : INFO : EPOCH 3 - PROGRESS: at 44.61% examples, 694312 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:06,872 : INFO : EPOCH 3 - PROGRESS: at 47.17% examples, 692044 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 22:49:07,880 : INFO : EPOCH 3 - PROGRESS: at 49.37% examples, 687017 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:49:08,880 : INFO : EPOCH 3 - PROGRESS: at 51.47% examples, 682579 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:49:09,903 : INFO : EPOCH 3 - PROGRESS: at 53.81% examples, 682326 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:49:10,912 : INFO : EPOCH 3 - PROGRESS: at 56.41% examples, 682861 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:49:11,919 : INFO : EPOCH 3 - PROGRESS: at 58.91% examples, 682866 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:49:12,919 : INFO : EPOCH 3 - PROGRESS: at 61.40% examples, 683068 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:13,929 : INFO : EPOCH 3 - PROGRESS: at 64.22% examples, 684308 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:49:14,931 : INFO : EPOCH 3 - PROGRESS: at 66.80% examples, 686421 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:15,934 : INFO : EPOCH 3 - PROGRESS: at 69.54% examples, 689767 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:16,948 : INFO : EPOCH 3 - PROGRESS: at 71.96% examples, 690409 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 22:49:17,956 : INFO : EPOCH 3 - PROGRESS: at 74.74% examples, 692053 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:18,960 : INFO : EPOCH 3 - PROGRESS: at 76.99% examples, 692085 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:49:19,965 : INFO : EPOCH 3 - PROGRESS: at 79.38% examples, 692741 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:49:20,981 : INFO : EPOCH 3 - PROGRESS: at 82.03% examples, 694898 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:49:21,986 : INFO : EPOCH 3 - PROGRESS: at 84.51% examples, 695763 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:22,989 : INFO : EPOCH 3 - PROGRESS: at 87.14% examples, 696596 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:24,010 : INFO : EPOCH 3 - PROGRESS: at 89.64% examples, 695676 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:49:25,029 : INFO : EPOCH 3 - PROGRESS: at 92.27% examples, 695534 words/s, in_qsize 19, out_qsize 2
# 2020-04-01 22:49:26,041 : INFO : EPOCH 3 - PROGRESS: at 95.04% examples, 697776 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:49:27,049 : INFO : EPOCH 3 - PROGRESS: at 97.26% examples, 695528 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:49:28,064 : INFO : EPOCH 3 - PROGRESS: at 99.68% examples, 694514 words/s, in_qsize 13, out_qsize 0
# 2020-04-01 22:49:28,113 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:49:28,119 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:49:28,121 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:49:28,125 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:49:28,129 : INFO : worker thread finished; awaiting finish of 5 more threads
# ...
# 2020-04-01 22:52:23,211 : INFO : EPOCH 8 - PROGRESS: at 27.29% examples, 721129 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:52:24,219 : INFO : EPOCH 8 - PROGRESS: at 30.03% examples, 721698 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:52:25,228 : INFO : EPOCH 8 - PROGRESS: at 33.11% examples, 726400 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:26,231 : INFO : EPOCH 8 - PROGRESS: at 35.62% examples, 725408 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:27,236 : INFO : EPOCH 8 - PROGRESS: at 37.85% examples, 718113 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:28,237 : INFO : EPOCH 8 - PROGRESS: at 40.31% examples, 714256 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:29,238 : INFO : EPOCH 8 - PROGRESS: at 42.98% examples, 713445 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:52:30,253 : INFO : EPOCH 8 - PROGRESS: at 45.83% examples, 714191 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:52:31,257 : INFO : EPOCH 8 - PROGRESS: at 48.41% examples, 714297 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:32,284 : INFO : EPOCH 8 - PROGRESS: at 50.90% examples, 711418 words/s, in_qsize 20, out_qsize 4
# 2020-04-01 22:52:33,290 : INFO : EPOCH 8 - PROGRESS: at 53.09% examples, 708686 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:34,296 : INFO : EPOCH 8 - PROGRESS: at 55.54% examples, 706500 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:35,309 : INFO : EPOCH 8 - PROGRESS: at 58.15% examples, 706742 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:36,311 : INFO : EPOCH 8 - PROGRESS: at 60.63% examples, 705686 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:52:37,318 : INFO : EPOCH 8 - PROGRESS: at 63.13% examples, 704795 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:52:38,327 : INFO : EPOCH 8 - PROGRESS: at 65.73% examples, 703944 words/s, in_qsize 16, out_qsize 5
# 2020-04-01 22:52:39,334 : INFO : EPOCH 8 - PROGRESS: at 68.24% examples, 703938 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:40,338 : INFO : EPOCH 8 - PROGRESS: at 70.74% examples, 705262 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:52:41,339 : INFO : EPOCH 8 - PROGRESS: at 73.64% examples, 708253 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:42,341 : INFO : EPOCH 8 - PROGRESS: at 75.92% examples, 707377 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:52:43,350 : INFO : EPOCH 8 - PROGRESS: at 78.27% examples, 707711 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:52:44,358 : INFO : EPOCH 8 - PROGRESS: at 80.86% examples, 709073 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:45,361 : INFO : EPOCH 8 - PROGRESS: at 83.45% examples, 709807 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:46,391 : INFO : EPOCH 8 - PROGRESS: at 86.09% examples, 711469 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:52:47,414 : INFO : EPOCH 8 - PROGRESS: at 88.64% examples, 709638 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:52:48,425 : INFO : EPOCH 8 - PROGRESS: at 91.27% examples, 709667 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:49,425 : INFO : EPOCH 8 - PROGRESS: at 93.87% examples, 710328 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:52:50,426 : INFO : EPOCH 8 - PROGRESS: at 96.55% examples, 711219 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:51,430 : INFO : EPOCH 8 - PROGRESS: at 99.06% examples, 710518 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:51,750 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:52:51,752 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:52:51,754 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:52:51,773 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:52:51,784 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:52:51,787 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:52:51,791 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:52:51,794 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:52:51,799 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:52:51,816 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:52:51,820 : INFO : EPOCH - 8 : training on 41519358 raw words (28926290 effective words) took 40.7s, 709989 effective words/s
# 2020-04-01 22:52:52,859 : INFO : EPOCH 9 - PROGRESS: at 1.95% examples, 569425 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:53,864 : INFO : EPOCH 9 - PROGRESS: at 4.24% examples, 613687 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:52:54,887 : INFO : EPOCH 9 - PROGRESS: at 6.75% examples, 649238 words/s, in_qsize 19, out_qsize 2
# 2020-04-01 22:52:55,903 : INFO : EPOCH 9 - PROGRESS: at 9.22% examples, 674125 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:52:56,906 : INFO : EPOCH 9 - PROGRESS: at 11.16% examples, 677189 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:52:57,934 : INFO : EPOCH 9 - PROGRESS: at 13.16% examples, 675808 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:52:58,957 : INFO : EPOCH 9 - PROGRESS: at 15.27% examples, 675712 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:52:59,971 : INFO : EPOCH 9 - PROGRESS: at 17.27% examples, 675268 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:53:00,990 : INFO : EPOCH 9 - PROGRESS: at 19.31% examples, 679920 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:02,000 : INFO : EPOCH 9 - PROGRESS: at 20.87% examples, 670245 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:03,004 : INFO : EPOCH 9 - PROGRESS: at 23.16% examples, 674305 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:04,023 : INFO : EPOCH 9 - PROGRESS: at 25.24% examples, 674652 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:05,061 : INFO : EPOCH 9 - PROGRESS: at 27.99% examples, 674647 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:53:06,073 : INFO : EPOCH 9 - PROGRESS: at 30.62% examples, 676905 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:07,090 : INFO : EPOCH 9 - PROGRESS: at 33.15% examples, 674891 words/s, in_qsize 14, out_qsize 5
# 2020-04-01 22:53:08,093 : INFO : EPOCH 9 - PROGRESS: at 35.70% examples, 677496 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:09,128 : INFO : EPOCH 9 - PROGRESS: at 38.24% examples, 676621 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:10,184 : INFO : EPOCH 9 - PROGRESS: at 40.92% examples, 677086 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:11,191 : INFO : EPOCH 9 - PROGRESS: at 43.65% examples, 678473 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:12,195 : INFO : EPOCH 9 - PROGRESS: at 46.52% examples, 682123 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:13,209 : INFO : EPOCH 9 - PROGRESS: at 48.83% examples, 679588 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:14,212 : INFO : EPOCH 9 - PROGRESS: at 51.24% examples, 678803 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:15,237 : INFO : EPOCH 9 - PROGRESS: at 53.64% examples, 679187 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:53:16,245 : INFO : EPOCH 9 - PROGRESS: at 56.32% examples, 680790 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:53:17,246 : INFO : EPOCH 9 - PROGRESS: at 58.39% examples, 676651 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:18,259 : INFO : EPOCH 9 - PROGRESS: at 60.38% examples, 671306 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:19,274 : INFO : EPOCH 9 - PROGRESS: at 62.73% examples, 670019 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:20,291 : INFO : EPOCH 9 - PROGRESS: at 65.37% examples, 669996 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:21,295 : INFO : EPOCH 9 - PROGRESS: at 67.81% examples, 670934 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:22,305 : INFO : EPOCH 9 - PROGRESS: at 70.15% examples, 671818 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 22:53:23,312 : INFO : EPOCH 9 - PROGRESS: at 72.67% examples, 673020 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:53:24,319 : INFO : EPOCH 9 - PROGRESS: at 75.12% examples, 673362 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:25,344 : INFO : EPOCH 9 - PROGRESS: at 77.24% examples, 672148 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:53:26,368 : INFO : EPOCH 9 - PROGRESS: at 79.34% examples, 670170 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:27,396 : INFO : EPOCH 9 - PROGRESS: at 81.65% examples, 670206 words/s, in_qsize 17, out_qsize 3
# 2020-04-01 22:53:28,409 : INFO : EPOCH 9 - PROGRESS: at 84.19% examples, 671388 words/s, in_qsize 19, out_qsize 4
# 2020-04-01 22:53:29,412 : INFO : EPOCH 9 - PROGRESS: at 86.69% examples, 672650 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:30,412 : INFO : EPOCH 9 - PROGRESS: at 89.43% examples, 674172 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:31,413 : INFO : EPOCH 9 - PROGRESS: at 92.07% examples, 675244 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:53:32,439 : INFO : EPOCH 9 - PROGRESS: at 94.28% examples, 673582 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:53:33,445 : INFO : EPOCH 9 - PROGRESS: at 96.46% examples, 671899 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:34,454 : INFO : EPOCH 9 - PROGRESS: at 98.83% examples, 671275 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:34,831 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:53:34,834 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:53:34,835 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:53:34,837 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:53:34,839 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:53:34,852 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:53:34,860 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:53:34,865 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:53:34,867 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:53:34,869 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:53:34,871 : INFO : EPOCH - 9 : training on 41519358 raw words (28924236 effective words) took 43.0s, 672138 effective words/s
# 2020-04-01 22:53:35,888 : INFO : EPOCH 10 - PROGRESS: at 2.11% examples, 630307 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:36,894 : INFO : EPOCH 10 - PROGRESS: at 4.54% examples, 668107 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:53:37,909 : INFO : EPOCH 10 - PROGRESS: at 7.12% examples, 691827 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:38,922 : INFO : EPOCH 10 - PROGRESS: at 9.44% examples, 697693 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:39,939 : INFO : EPOCH 10 - PROGRESS: at 11.51% examples, 703614 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:40,951 : INFO : EPOCH 10 - PROGRESS: at 13.50% examples, 696444 words/s, in_qsize 20, out_qsize 3
# 2020-04-01 22:53:41,968 : INFO : EPOCH 10 - PROGRESS: at 15.73% examples, 698039 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:42,972 : INFO : EPOCH 10 - PROGRESS: at 17.80% examples, 703076 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:53:43,989 : INFO : EPOCH 10 - PROGRESS: at 19.85% examples, 705687 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:45,017 : INFO : EPOCH 10 - PROGRESS: at 22.24% examples, 709575 words/s, in_qsize 20, out_qsize 1
# 2020-04-01 22:53:46,037 : INFO : EPOCH 10 - PROGRESS: at 24.24% examples, 711507 words/s, in_qsize 20, out_qsize 2
# 2020-04-01 22:53:47,048 : INFO : EPOCH 10 - PROGRESS: at 27.02% examples, 713891 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:48,060 : INFO : EPOCH 10 - PROGRESS: at 29.92% examples, 716837 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:49,094 : INFO : EPOCH 10 - PROGRESS: at 32.71% examples, 716331 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:50,115 : INFO : EPOCH 10 - PROGRESS: at 34.97% examples, 710507 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:51,139 : INFO : EPOCH 10 - PROGRESS: at 37.43% examples, 706838 words/s, in_qsize 17, out_qsize 6
# 2020-04-01 22:53:52,139 : INFO : EPOCH 10 - PROGRESS: at 40.23% examples, 708830 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:53,172 : INFO : EPOCH 10 - PROGRESS: at 42.92% examples, 707813 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:53:54,180 : INFO : EPOCH 10 - PROGRESS: at 45.52% examples, 705129 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:55,201 : INFO : EPOCH 10 - PROGRESS: at 48.01% examples, 704492 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:56,222 : INFO : EPOCH 10 - PROGRESS: at 50.68% examples, 704201 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:53:57,239 : INFO : EPOCH 10 - PROGRESS: at 53.12% examples, 704507 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:58,254 : INFO : EPOCH 10 - PROGRESS: at 55.91% examples, 706111 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:53:59,263 : INFO : EPOCH 10 - PROGRESS: at 58.44% examples, 705843 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:54:00,269 : INFO : EPOCH 10 - PROGRESS: at 60.99% examples, 705286 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:54:01,276 : INFO : EPOCH 10 - PROGRESS: at 63.67% examples, 705373 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:54:02,284 : INFO : EPOCH 10 - PROGRESS: at 66.41% examples, 707087 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:54:03,285 : INFO : EPOCH 10 - PROGRESS: at 69.07% examples, 708830 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:54:04,300 : INFO : EPOCH 10 - PROGRESS: at 71.59% examples, 709715 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:54:05,313 : INFO : EPOCH 10 - PROGRESS: at 74.32% examples, 710672 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:54:06,319 : INFO : EPOCH 10 - PROGRESS: at 76.80% examples, 712062 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:54:07,330 : INFO : EPOCH 10 - PROGRESS: at 79.11% examples, 711346 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:54:08,368 : INFO : EPOCH 10 - PROGRESS: at 81.37% examples, 709274 words/s, in_qsize 16, out_qsize 3
# 2020-04-01 22:54:09,387 : INFO : EPOCH 10 - PROGRESS: at 83.62% examples, 706859 words/s, in_qsize 19, out_qsize 1
# 2020-04-01 22:54:10,389 : INFO : EPOCH 10 - PROGRESS: at 85.61% examples, 703715 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:54:11,392 : INFO : EPOCH 10 - PROGRESS: at 88.01% examples, 701720 words/s, in_qsize 19, out_qsize 0
# 2020-04-01 22:54:12,394 : INFO : EPOCH 10 - PROGRESS: at 90.32% examples, 699746 words/s, in_qsize 18, out_qsize 1
# 2020-04-01 22:54:13,435 : INFO : EPOCH 10 - PROGRESS: at 92.76% examples, 698334 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:54:14,478 : INFO : EPOCH 10 - PROGRESS: at 95.52% examples, 699295 words/s, in_qsize 20, out_qsize 0
# 2020-04-01 22:54:15,476 : INFO : EPOCH 10 - PROGRESS: at 97.91% examples, 698620 words/s, in_qsize 17, out_qsize 2
# 2020-04-01 22:54:16,188 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-04-01 22:54:16,199 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-04-01 22:54:16,201 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-04-01 22:54:16,207 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-04-01 22:54:16,211 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-04-01 22:54:16,219 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-04-01 22:54:16,226 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-01 22:54:16,233 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-01 22:54:16,240 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-01 22:54:16,254 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-01 22:54:16,257 : INFO : EPOCH - 10 : training on 41519358 raw words (28920955 effective words) took 41.4s, 699092 effective words/s
# 2020-04-01 22:54:16,260 : INFO : training on a 415193580 raw words (289238871 effective words) took 410.8s, 704013 effective words/s
# (289238871, 415193580)

# %%
print(model)
# Out:
# Word2Vec(vocab=5532, size=150, alpha=0.025)

# %% [markdown]
# ## Now, let's look at some output
# This first example shows a simple case of looking up words similar to the word `dirty`. All we need to do here is to call the `most_similar` function and provide the word `dirty` as the positive example. This returns the top 10 similar words.

# %%
model.wv.most_similar(positive=['king','man'], negative=['woman'])
# Out:
# 2020-04-01 22:54:16,501 : INFO : precomputing L2-norms of word weight vectors
# [('queen', 0.7203969955444336),
#  ('double', 0.6152127981185913),
#  ('kingsize', 0.6099899411201477),
#  ('twin', 0.5580258369445801),
#  ('kings', 0.4558507204055786),
#  ('triple', 0.44984766840934753),
#  ('bunk', 0.43198803067207336),
#  ('suite', 0.4273955523967743),
#  ('rollaway', 0.41280534863471985),
#  ('charing', 0.4126197099685669)]

# %%
w1 = "dirty"
model.wv.most_similar(positive=w1)
# Out:
# [('filthy', 0.8791720867156982),
#  ('stained', 0.7720414400100708),
#  ('smelly', 0.7702115178108215),
#  ('dusty', 0.755642831325531),
#  ('grubby', 0.7412349581718445),
#  ('unclean', 0.7402980923652649),
#  ('disgusting', 0.7364978194236755),
#  ('dingy', 0.7328251004219055),
#  ('gross', 0.7076297998428345),
#  ('mouldy', 0.7025498151779175)]

# %% [markdown]
# That looks pretty good, right? Let's look at a few more. Let's look at similarity for `polite`, `france` and `shocked`.

# %%
# look up top 6 words similar to 'polite'
w1 = ["polite"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('courteous', 0.9245035648345947),
#  ('friendly', 0.8243503570556641),
#  ('professional', 0.7840369343757629),
#  ('attentive', 0.7738608717918396),
#  ('cordial', 0.7705366611480713),
#  ('gracious', 0.7484797835350037)]

# %%
# look up top 6 words similar to 'france'
w1 = ["france"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('canada', 0.6424276232719421),
#  ('england', 0.6046283841133118),
#  ('asia', 0.5742356777191162),
#  ('ireland', 0.5466592907905579),
#  ('scotland', 0.5334623456001282),
#  ('paris', 0.5188875198364258)]

# %%
# look up top 6 words similar to 'shocked'
w1 = ["shocked"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('amazed', 0.8201600313186646),
#  ('surprised', 0.7175366282463074),
#  ('suprised', 0.7146936058998108),
#  ('relieved', 0.6769506335258484),
#  ('disgusted', 0.62152099609375),
#  ('upset', 0.5996388792991638)]

# %% [markdown]
# That's, nice. You can even specify several positive examples to get things that are related in the provided context and provide negative examples to say what should not be considered as related. In the example below we are asking for all items that *relate to bed* only:

# %%
# get everything related to stuff on the bed
w1 = ["bed",'sheet','pillow']
w2 = ['couch']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# [('duvet', 0.715502917766571),
#  ('mattress', 0.7075930833816528),
#  ('blanket', 0.6998939514160156),
#  ('matress', 0.662861168384552),
#  ('sheets', 0.6328041553497314),
#  ('pillows', 0.6319566965103149),
#  ('foam', 0.6283947229385376),
#  ('comforter', 0.6003474593162537),
#  ('blankets', 0.5892742276191711),
#  ('mattresses', 0.5428688526153564)]

# %%
model.wv.most_similar (positive=w1,topn=10)
# Out:
# [('mattress', 0.8143635392189026),
#  ('duvet', 0.7732292413711548),
#  ('blanket', 0.7570896744728088),
#  ('matress', 0.7531951069831848),
#  ('pillows', 0.6970942616462708),
#  ('sheets', 0.6624629497528076),
#  ('comforter', 0.6602129340171814),
#  ('foam', 0.6410971879959106),
#  ('blankets', 0.6294257044792175),
#  ('bedspread', 0.610710859298706)]

# %% [markdown]
# ### Similarity between two words in the vocabulary

# %% [markdown]
# You can even use the Word2Vec model to return the similarity between two words that are present in the vocabulary.

# %%
# similarity between two different words
model.wv.similarity(w1="dirty",w2="smelly")
# Out:
# 0.7702115

# %%
# similarity between two identical words
model.wv.similarity(w1="dirty",w2="dirty")
# Out:
# 1.0

# %%
# similarity between two unrelated words
model.wv.similarity(w1="dirty",w2="clean")
# Out:
# 0.26266825

# %% [markdown]
# Under the hood, the above three snippets computes the cosine similarity between the two specified words using word vectors of each. From the scores, it makes sense that `dirty` is highly similar to `smelly` but `dirty` is dissimilar to `clean`. If you do a similarity between two identical words, the score will be 1.0 as the range of the cosine similarity score will always be between [0.0-1.0]. You can read more about cosine similarity scoring [here](https://en.wikipedia.org/wiki/Cosine_similarity).

# %% [markdown]
# ### Find the odd one out
# You can even use Word2Vec to find odd items given a list of items.

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# C:\Users\bruno\Anaconda3\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'france'

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["bed","pillow","duvet","shower"])
# Out:
# 'shower'

# %%
from itertools import islice

def take(n, iterable):
    "Return first n items of the iterable as a list"
    return list(islice(iterable, n))

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in take(300, model.wv.vocab):
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
tsne_plot(model)
# Out:
# C:\Users\bruno\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys

# %% [markdown]
# ## Understanding some of the parameters
# To train the model earlier, we had to set some parameters. Now, let's try to understand what some of them mean. For reference, this is the command that we used to train the model.
#
# ```
# model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
# ```
#
# ### `size`
# The size of the dense vector to represent each token or word. If you have very limited data, then size should be a much smaller value. If you have lots of data, its good to experiment with various sizes. A value of 100-150 has worked well for me.
#
# ### `window`
# The maximum distance between the target word and its neighboring word. If your neighbor's position is greater than the maximum window width to the left and the right, then, some neighbors are not considered as being related to the target word. In theory, a smaller window should give you terms that are more related. If you have lots of data, then the window size should not matter too much, as long as its a decent sized window.
#
# ### `min_count`
# Minimium frequency count of words. The model would ignore words that do not statisfy the `min_count`. Extremely infrequent words are usually unimportant, so its best to get rid of those. Unless your dataset is really tiny, this does not really affect the model.
#
# ### `workers`
# How many threads to use behind the scenes?

# %% [markdown]
# ## When should you use Word2Vec?
#
# There are many application scenarios for Word2Vec. Imagine if you need to build a sentiment lexicon. Training a Word2Vec model on large amounts of user reviews helps you achieve that. You have a lexicon for not just sentiment, but for most words in the vocabulary.
#
# Beyond, raw unstructured text data, you could also use Word2Vec for more structured data. For example, if you had tags for a million stackoverflow questions and answers, you could find tags that are related to a given tag and recommend the related ones for exploration. You can do this by treating each set of co-occuring tags as a "sentence" and train a Word2Vec model on this data. Granted, you still need a large number of examples to make it work.
